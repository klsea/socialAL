# %% [markdown]
# ### SocialAL Models
# # Fit gain-loss learning model to subset of data
# KLS 12.18.22
# Project info: https://osf.io/b48n2/
#
# Model modified from :
# Fareri, D. S., Chang, L. J., & Delgado, M. R. (2012). Effects of direct social experience on trust decisions and neural reward circuitry. Frontiers in Neuroscience, 6, 1–17. https://doi.org/10.3389/fnins.2012.00148

# %% [markdown]
# ### Python version

# %%
import sys
print(sys.version)
# Out:
# 3.11.0 (v3.11.0:deaf509e8f, Oct 24 2022, 14:43:23) [Clang 13.0.0 (clang-1300.0.29.30)]

# %% [markdown]
# ### Load modules

# %%
import numpy as np
import random
import math
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import itertools
import os
import csv

# %% [markdown]
# ## Pull in functions

# %%
run common_functions.ipynb

# %%
run double_alpha_functions.ipynb

# %% [markdown]
# ### New function to fit model to multiple subjects

# %%
def model_fit_mult_subject(data):
    pdt = pd.DataFrame(columns = ['Subject','a_gain', 'a_loss', 'beta', 'llh'])
    a = pd.unique(data['Subject'])
    #print(a)
    for sub in range(len(a)):
        print('Subject: ', a[sub])
        df = data[data['Subject']==a[sub]]
        df.dropna()
        df.reset_index(drop=True, inplace=True)
        dt = df.to_dict()
        params = model_fit(dt)
        #print('Params: ', params)
        line = {'Subject': sub, 'a_gain':params[0], 'a_loss':params[1], 'beta':params[2], 'llh':params[3]}
        pdt = pdt.append(line, ignore_index=True)   
    return(pdt)

# %% [markdown]
# ### Load and clean data

# %%
files = os.listdir('../../data/modeling')
files.remove('.DS_Store')
files.remove('missing')
#print(files)

# %%
n_part = len(files)
print('number of participants: ', n_part)
# Out:
# number of participants:  63

# %%
def load_and_clean(file):
    path = os.path.join('../../data/modeling', file)
    dt = pd.read_csv(path)
    # recode trial type into numbers for model
    def stims(trial_type):
        if trial_type == "Trustworthy":
            return 0
        elif trial_type == "Neutral":
            return 1
        elif trial_type == "Untrustworthy":
            return 2
    dt['Stim_Sequence'] = dt['trial_type'].apply(stims)
    # rename response_key to choice
    def choices(response_key):
        if response_key == 'None':
            return 0 
        else:
            return response_key  
    dt['Choice'] = dt['response_key'].apply(choices)
    dt['Choice'] = pd.to_numeric(dt['Choice'])
    # calculte the trustee response
    def resp(trial_earnings):
        if trial_earnings >= 12:
            return 1
        else:
            return 0
    dt['Trustee_Response'] = dt['trial_earnings'].apply(resp)
    data = dt[['Stim_Sequence','Choice', 'Trustee_Response']]
    # remove neutral trials
    data = data[data['Stim_Sequence'] != 1]
    data.reset_index(drop=True, inplace=True)
    return(data)

# %%
# data = load_and_clean(files[0])
# data.head(5)

# %%
# create csv file
file = open('../../output/generalization_criterion/a2_fit2_2cond_part.csv', 'w')

# add header
headerList = ['id', 'alpha_gain', 'alpha_loss', 'beta', 'llh']
with open('../../output/generalization_criterion/a2_fit2_2cond_part.csv', 'a') as f_object: 
    dw = csv.DictWriter(f_object, delimiter = ',', fieldnames = headerList)
    dw.writeheader()

#loop thru participants
for x in range(n_part):
    print('loop:', x)
    subject = files[x][:-4]
    print(subject)
    
    # load and clean data
    print('loading data')
    data = load_and_clean(files[x])
    
    # fit model
    print('fitting model')
    a2 = model_fit(data)
    a2 = np.array(a2).tolist()
    a2.insert(0,subject)
    print(a2)
    
    # save results
    print('saving results')
    with open('../../output/generalization_criterion/a2_fit2_2cond_part.csv', 'a') as f_object: # create a file object
        writer_object = csv.writer(f_object) # pass the file object to csv writer
        writer_object.writerow(a2) #pass list as argument to writerow
        f_object.close() # close the file object
# Out:
# loop: 0
# sub-2013
# loading data
# fitting model
# ['sub-2013', 0.0027306462676590483, 0.002246281213341411, 20.0, 32.36687551065146]
# saving results
# loop: 1
# sub-2007
# loading data
# fitting model
# ['sub-2007', 0.24739415362125183, 0.20070657950612308, 0.30391080096952855, 35.88413813569691]
# saving results
# loop: 2
# sub-2006
# loading data
# fitting model
# ['sub-2006', 0.0, 0.0, 1e-10, 41.588830833596695]
# saving results
# loop: 3
# sub-2012
# loading data
# fitting model
# ['sub-2012', 0.05004324514055666, 1.0, 0.3805524678837031, 32.66263226531049]
# saving results
# loop: 4
# sub-2004
# loading data
# fitting model
# ['sub-2004', 1.0, 0.08842572254716502, 2.279855365624818, 12.709589994979053]
# saving results
# loop: 5
# sub-2010
# loading data
# fitting model
# ['sub-2010', 0.0, 0.00045177597250083395, 9.748828939817987, 38.77342108312972]
# saving results
# loop: 6
# sub-2038
# loading data
# fitting model
# ['sub-2038', 0.722364206950194, 0.0, 0.055173818044008276, 41.38101106620432]
# saving results
# loop: 7
# sub-2039
# loading data
# fitting model
# ['sub-2039', 1.0, 0.0104699143371584, 20.0, 9.996874280829758]
# saving results
# loop: 8
# sub-2011
# loading data
# fitting model
# ['sub-2011', 0.06780850186255709, 0.5082528377265108, 0.30494891359575177, 35.29838649183502]
# saving results
# loop: 9
# sub-2005
# loading data
# fitting model
# ['sub-2005', 0.0, 0.0005920077380588897, 20.0, 38.29210964136358]
# saving results
# loop: 10
# sub-2001
# loading data
# fitting model
# ['sub-2001', 0.20763265856836569, 0.8835305339206956, 0.5611990869518231, 24.28363657276476]
# saving results
# loop: 11
# sub-2002
# loading data
# fitting model
# ['sub-2002', 0.03189669735866511, 0.36345625371083184, 0.09526175895224505, 41.04595804927451]
# saving results
# loop: 12
# sub-2003
# loading data
# fitting model
# ['sub-2003', 0.2316611535939296, 0.9660755730586326, 0.2376561575087608, 32.85559042112412]
# saving results
# loop: 13
# sub-1009
# loading data
# fitting model
# ['sub-1009', 0.0003465550367246052, 0.0016309545622373094, 20.0, 38.75559517436949]
# saving results
# loop: 14
# sub-1021
# loading data
# fitting model
# ['sub-1021', 0.024689096761790676, 0.036974291222040725, 6.937137819853354, 14.966752494622655]
# saving results
# loop: 15
# sub-1035
# loading data
# fitting model
# ['sub-1035', 1.0, 0.472417935104018, 0.36506875434841113, 28.552868238729452]
# saving results
# loop: 16
# sub-1034
# loading data
# fitting model
# ['sub-1034', 0.006307270486513223, 0.006322428812154955, 20.0, 19.909494372237855]
# saving results
# loop: 17
# sub-1020
# loading data
# fitting model
# ['sub-1020', 0.024564514713263094, 0.21584500098733167, 3.3935242683906877, 15.131379758887167]
# saving results
# loop: 18
# sub-1008
# loading data
# fitting model
# ['sub-1008', 0.011255058128458718, 1.0, 3.5368513279064144, 19.905461182661348]
# saving results
# loop: 19
# sub-1036
# loading data
# fitting model
# ['sub-1036', 1.0, 0.0797554145714743, 0.7163427000494866, 24.65879005578193]
# saving results
# loop: 20
# sub-1022
# loading data
# fitting model
# ['sub-1022', 0.0012684763719726727, 0.004979297356323667, 20.0, 32.37430287900308]
# saving results
# loop: 21
# sub-1023
# loading data
# fitting model
# ['sub-1023', 0.8107599655056927, 0.6868135744475955, 0.4915624535709597, 23.8934719692155]
# saving results
# loop: 22
# sub-1037
# loading data
# fitting model
# ['sub-1037', 0.003564233297083331, 0.003030735477963882, 20.0, 28.332712846476426]
# saving results
# loop: 23
# sub-1033
# loading data
# fitting model
# ['sub-1033', 0.0025656397471952846, 0.02086016154529003, 20.0, 21.923393568670797]
# saving results
# loop: 24
# sub-1026
# loading data
# fitting model
# ['sub-1026', 0.0, 0.001356179232498691, 20.0, 38.212079369349944]
# saving results
# loop: 25
# sub-1032
# loading data
# fitting model
# ['sub-1032', 0.0014145049443555966, 0.014137967112349452, 20.0, 31.615689711028395]
# saving results
# loop: 26
# sub-1024
# loading data
# fitting model
# ['sub-1024', 1.0, 1.0, 20.0, 2.772588722239781]
# saving results
# loop: 27
# sub-1030
# loading data
# fitting model
# ['sub-1030', 0.001864890184699823, 0.03949693819434334, 20.0, 20.596304273702035]
# saving results
# loop: 28
# sub-1018
# loading data
# fitting model
# ['sub-1018', 4.759016533399744e-05, 0.004721024720478725, 20.0, 33.24824205458284]
# saving results
# loop: 29
# sub-1019
# loading data
# fitting model
# ['sub-1019', 0.005017243325049239, 0.01883118507731738, 20.0, 15.008393146674674]
# saving results
# loop: 30
# sub-1025
# loading data
# fitting model
# ['sub-1025', 0.0, 0.002123761327283973, 20.0, 37.31285995288652]
# saving results
# loop: 31
# sub-1028
# loading data
# fitting model
# ['sub-1028', 0.0032261581458508924, 0.006896937365991113, 20.0, 24.106681886399357]
# saving results
# loop: 32
# sub-1014
# loading data
# fitting model
# ['sub-1014', 0.08180321759277787, 1.0, 0.32305814550184875, 34.87858247965137]
# saving results
# loop: 33
# sub-1015
# loading data
# fitting model
# ['sub-1015', 0.8563701790349031, 0.6253379708729238, 0.4431473316625842, 24.62671856256544]
# saving results
# loop: 34
# sub-1029
# loading data
# fitting model
# ['sub-1029', 0.9977786177774087, 0.003442330975587688, 20.0, 15.191928126519635]
# saving results
# loop: 35
# sub-1017
# loading data
# fitting model
# ['sub-1017', 0.001952178385600924, 0.01588934799382281, 20.0, 20.68305099374445]
# saving results
# loop: 36
# sub-1016
# loading data
# fitting model
# ['sub-1016', 0.0, 0.04291727636093544, 20.0, 27.098615006287716]
# saving results
# loop: 37
# sub-1012
# loading data
# fitting model
# ['sub-1012', 0.017582171388201395, 0.008477538513553085, 20.0, 13.21023649116303]
# saving results
# loop: 38
# sub-1006
# loading data
# fitting model
# ['sub-1006', 0.00021375718157289162, 0.006147744603413038, 20.0, 31.365678694234305]
# saving results
# loop: 39
# sub-1007
# loading data
# fitting model
# ['sub-1007', 0.2643096954793927, 0.9969987596673218, 0.5328132329790838, 22.481470617375617]
# saving results
# loop: 40
# sub-1013
# loading data
# fitting model
# ['sub-1013', 0.0015732340008841623, 0.008671508510210592, 20.0, 29.974375800812755]
# saving results
# loop: 41
# sub-1005
# loading data
# fitting model
# ['sub-1005', 0.0022350666097633387, 0.011461680401217967, 20.0, 22.594414393330513]
# saving results
# loop: 42
# sub-1039
# loading data
# fitting model
# ['sub-1039', 1.0, 0.01820755632558166, 20.0, 7.868637561820535]
# saving results
# loop: 43
# sub-1038
# loading data
# fitting model
# ['sub-1038', 0.004439412716348377, 1.0, 20.0, 13.728590909498]
# saving results
# loop: 44
# sub-1010
# loading data
# fitting model
# ['sub-1010', 0.004449378252359886, 0.0089195599784867, 12.693155357423999, 27.040572435947734]
# saving results
# loop: 45
# sub-1004
# loading data
# fitting model
# ['sub-1004', 0.14255698316072063, 0.14408196065700804, 0.6590211403661548, 28.572738884821856]
# saving results
# loop: 46
# sub-2026
# loading data
# fitting model
# ['sub-2026', 1.0, 0.0, 0.6114051991695253, 27.68502583015162]
# saving results
# loop: 47
# sub-2027
# loading data
# fitting model
# ['sub-2027', 0.056973854246095176, 0.047550865263654866, 1.1199857708828227, 31.225812999042724]
# saving results
# loop: 48
# sub-2033
# loading data
# fitting model
# ['sub-2033', 1.0, 1.0, 0.051629805181229074, 39.81662184302518]
# saving results
# loop: 49
# sub-2025
# loading data
# fitting model
# ['sub-2025', 0.1571496593183521, 0.42957408902122607, 0.4512773707094187, 30.07318844650833]
# saving results
# loop: 50
# sub-2031
# loading data
# fitting model
# ['sub-2031', 0.0, 0.0006078339717066201, 20.0, 39.57767393583031]
# saving results
# loop: 51
# sub-2019
# loading data
# fitting model
# ['sub-2019', 0.0, 0.020002123722444483, 19.264808743778932, 28.124076952607282]
# saving results
# loop: 52
# sub-2018
# loading data
# fitting model
# ['sub-2018', 0.025552198952140864, 0.0012606620582229183, 20.0, 21.825550631145383]
# saving results
# loop: 53
# sub-2030
# loading data
# fitting model
# ['sub-2030', 0.5804146402232824, 0.0, 0.02270117858776867, 38.78411384317456]
# saving results
# loop: 54
# sub-2024
# loading data
# fitting model
# ['sub-2024', 0.1626957066453213, 0.2196639592909168, 1.142199948024197, 19.275875557276887]
# saving results
# loop: 55
# sub-2020
# loading data
# fitting model
# ['sub-2020', 0.0025099375553005727, 0.028355731812671505, 20.0, 22.758867564238347]
# saving results
# loop: 56
# sub-2034
# loading data
# fitting model
# ['sub-2034', 1.0, 0.0, 20.0, 22.18070977791825]
# saving results
# loop: 57
# sub-2021
# loading data
# fitting model
# ['sub-2021', 0.009810821201308557, 0.06276087344398644, 2.666904461821187, 32.7612117927655]
# saving results
# loop: 58
# sub-2009
# loading data
# fitting model
# ['sub-2009', 0.0, 1.0, 0.08134188451141118, 40.68135182952405]
# saving results
# loop: 59
# sub-2037
# loading data
# fitting model
# ['sub-2037', 0.0010630518311920073, 0.005036437418863744, 20.0, 30.777883306847965]
# saving results
# loop: 60
# sub-2023
# loading data
# fitting model
# ['sub-2023', 0.01758232917333357, 0.020756693839587288, 20.0, 11.581743239181527]
# saving results
# loop: 61
# sub-2022
# loading data
# fitting model
# ['sub-2022', 0.0, 0.2970056383076636, 0.04297865203612075, 41.49658537896364]
# saving results
# loop: 62
# sub-2036
# loading data
# fitting model
# ['sub-2036', 0.00022559481038672457, 0.0, 5.445013108786405, 41.58332041076454]
# saving results

# %%
print(a2)
#a2.to_csv(path_or_buf = '../../output/simulation/a2_fit2_a2.csv', index = False)
# Out:
# ['sub-2036', 0.00022559481038672457, 0.0, 5.445013108786405, 41.58332041076454]
