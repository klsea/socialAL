# %% [markdown]
# ### SocialAL Models
# # Fit baseline learning model to subset of data
# KLS 12.19.22
# Project info: https://osf.io/b48n2/
#
# Model modified from :
# Fareri, D. S., Chang, L. J., & Delgado, M. R. (2012). Effects of direct social experience on trust decisions and neural reward circuitry. Frontiers in Neuroscience, 6, 1–17. https://doi.org/10.3389/fnins.2012.00148

# %% [markdown]
# ### Python version

# %%
import sys
print(sys.version)
# Out:
# 3.11.0 (v3.11.0:deaf509e8f, Oct 24 2022, 14:43:23) [Clang 13.0.0 (clang-1300.0.29.30)]

# %% [markdown]
# ### Load modules

# %%
import numpy as np
import random
import math
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import itertools
import os
import csv

# %% [markdown]
# ## Pull in functions

# %%
run common_functions.ipynb

# %%
run baseline_functions.ipynb

# %% [markdown]
# ### New function to fit model to multiple subjects

# %%
def model_fit_mult_subject(data):
    pdt = pd.DataFrame(columns = ['Subject','beta', 'llh'])
    a = pd.unique(data['Subject'])
    #print(a)
    for sub in range(len(a)):
        print('Subject: ', a[sub])
        df = data[data['Subject']==a[sub]]
        df.dropna()
        df.reset_index(drop=True, inplace=True)
        dt = df.to_dict()
        params = model_fit(dt)
        #print('Params: ', params)
        line = {'Subject': sub, 'beta':params[2], 'llh':params[3]}
        pdt = pdt.append(line, ignore_index=True)   
    return(pdt)

# %% [markdown]
# ### Load and clean data

# %%
files = os.listdir('../../data/modeling')
files.remove('.DS_Store')
files.remove('missing')
#print(files)

# %%
n_part = len(files)
print('number of participants: ', n_part)
# Out:
# number of participants:  63

# %%
def load_and_clean(file):
    path = os.path.join('../../data/modeling', file)
    dt = pd.read_csv(path)
    # recode trial type into numbers for model
    def stims(trial_type):
        if trial_type == "Trustworthy":
            return 0
        elif trial_type == "Neutral":
            return 1
        elif trial_type == "Untrustworthy":
            return 2
    dt['Stim_Sequence'] = dt['trial_type'].apply(stims)
    # rename response_key to choice
    def choices(response_key):
        if response_key == 'None':
            return 0 
        else:
            return response_key  
    dt['Choice'] = dt['response_key'].apply(choices)
    dt['Choice'] = pd.to_numeric(dt['Choice'])
    # calculte the trustee response
    def resp(trial_earnings):
        if trial_earnings >= 12:
            return 1
        else:
            return 0
    dt['Trustee_Response'] = dt['trial_earnings'].apply(resp)
    data = dt[['Stim_Sequence','Choice', 'Trustee_Response']]
    # remove neutral trials
    data = data[data['Stim_Sequence'] != 1]
    data.reset_index(drop=True, inplace=True)
    return(data)

# %%
# data = load_and_clean(files[0])
# data.head(5)

# %%
# create csv file
file = open('../../output/generalization_criterion/b_fit2_2cond_part.csv', 'w')

# add header
headerList = ['id', 'beta', 'llh']
with open('../../output/generalization_criterion/b_fit2_2cond_part.csv', 'a') as f_object: 
    dw = csv.DictWriter(f_object, delimiter = ',', fieldnames = headerList)
    dw.writeheader()

#loop thru participants
for x in range(n_part):
    print('loop:', x)
    subject = files[x][:-4]
    print(subject)
    
    # load and clean data
    print('loading data')
    data = load_and_clean(files[x])
    
    # fit model
    print('fitting model')
    bmf = model_fit(data)
    b = np.array(bmf.x).tolist()
    b.insert(0,subject)
    b.append(bmf.fun)
    #print(b)
    
    # save results
    print('saving results')
    with open('../../output/generalization_criterion/b_fit2_2cond_part.csv', 'a') as f_object: # create a file object
        writer_object = csv.writer(f_object) # pass the file object to csv writer
        writer_object.writerow(b) #pass list as argument to writerow
        f_object.close() # close the file object
# Out:
# loop: 0
# sub-2013
# loading data
# fitting model
# saving results
# loop: 1
# sub-2007
# loading data
# fitting model
# saving results
# loop: 2
# sub-2006
# loading data
# fitting model
# saving results
# loop: 3
# sub-2012
# loading data
# fitting model
# saving results
# loop: 4
# sub-2004
# loading data
# fitting model
# saving results
# loop: 5
# sub-2010
# loading data
# fitting model
# saving results
# loop: 6
# sub-2038
# loading data
# fitting model
# saving results
# loop: 7
# sub-2039
# loading data
# fitting model
# saving results
# loop: 8
# sub-2011
# loading data
# fitting model
# saving results
# loop: 9
# sub-2005
# loading data
# fitting model
# saving results
# loop: 10
# sub-2001
# loading data
# fitting model
# saving results
# loop: 11
# sub-2002
# loading data
# fitting model
# saving results
# loop: 12
# sub-2003
# loading data
# fitting model
# saving results
# loop: 13
# sub-1009
# loading data
# fitting model
# saving results
# loop: 14
# sub-1021
# loading data
# fitting model
# saving results
# loop: 15
# sub-1035
# loading data
# fitting model
# saving results
# loop: 16
# sub-1034
# loading data
# fitting model
# saving results
# loop: 17
# sub-1020
# loading data
# fitting model
# saving results
# loop: 18
# sub-1008
# loading data
# fitting model
# saving results
# loop: 19
# sub-1036
# loading data
# fitting model
# saving results
# loop: 20
# sub-1022
# loading data
# fitting model
# saving results
# loop: 21
# sub-1023
# loading data
# fitting model
# saving results
# loop: 22
# sub-1037
# loading data
# fitting model
# saving results
# loop: 23
# sub-1033
# loading data
# fitting model
# saving results
# loop: 24
# sub-1026
# loading data
# fitting model
# saving results
# loop: 25
# sub-1032
# loading data
# fitting model
# saving results
# loop: 26
# sub-1024
# loading data
# fitting model
# saving results
# loop: 27
# sub-1030
# loading data
# fitting model
# saving results
# loop: 28
# sub-1018
# loading data
# fitting model
# saving results
# loop: 29
# sub-1019
# loading data
# fitting model
# saving results
# loop: 30
# sub-1025
# loading data
# fitting model
# saving results
# loop: 31
# sub-1028
# loading data
# fitting model
# saving results
# loop: 32
# sub-1014
# loading data
# fitting model
# saving results
# loop: 33
# sub-1015
# loading data
# fitting model
# saving results
# loop: 34
# sub-1029
# loading data
# fitting model
# saving results
# loop: 35
# sub-1017
# loading data
# fitting model
# saving results
# loop: 36
# sub-1016
# loading data
# fitting model
# saving results
# loop: 37
# sub-1012
# loading data
# fitting model
# saving results
# loop: 38
# sub-1006
# loading data
# fitting model
# saving results
# loop: 39
# sub-1007
# loading data
# fitting model
# saving results
# loop: 40
# sub-1013
# loading data
# fitting model
# saving results
# loop: 41
# sub-1005
# loading data
# fitting model
# saving results
# loop: 42
# sub-1039
# loading data
# fitting model
# saving results
# loop: 43
# sub-1038
# loading data
# fitting model
# saving results
# loop: 44
# sub-1010
# loading data
# fitting model
# saving results
# loop: 45
# sub-1004
# loading data
# fitting model
# saving results
# loop: 46
# sub-2026
# loading data
# fitting model
# saving results
# loop: 47
# sub-2027
# loading data
# fitting model
# saving results
# loop: 48
# sub-2033
# loading data
# fitting model
# saving results
# loop: 49
# sub-2025
# loading data
# fitting model
# saving results
# loop: 50
# sub-2031
# loading data
# fitting model
# saving results
# loop: 51
# sub-2019
# loading data
# fitting model
# saving results
# loop: 52
# sub-2018
# loading data
# fitting model
# saving results
# loop: 53
# sub-2030
# loading data
# fitting model
# saving results
# loop: 54
# sub-2024
# loading data
# fitting model
# saving results
# loop: 55
# sub-2020
# loading data
# fitting model
# saving results
# loop: 56
# sub-2034
# loading data
# fitting model
# saving results
# loop: 57
# sub-2021
# loading data
# fitting model
# saving results
# loop: 58
# sub-2009
# loading data
# fitting model
# saving results
# loop: 59
# sub-2037
# loading data
# fitting model
# saving results
# loop: 60
# sub-2023
# loading data
# fitting model
# saving results
# loop: 61
# sub-2022
# loading data
# fitting model
# saving results
# loop: 62
# sub-2036
# loading data
# fitting model
# saving results
