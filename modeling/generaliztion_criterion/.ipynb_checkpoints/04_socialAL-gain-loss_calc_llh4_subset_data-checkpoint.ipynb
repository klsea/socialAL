# %% [markdown]
# ### SocialAL Models
# # Calc llh from gain-loss learning model for subset of data
# KLS 12.19.22
# Project info: https://osf.io/b48n2/
#
# Model modified from :
# Fareri, D. S., Chang, L. J., & Delgado, M. R. (2012). Effects of direct social experience on trust decisions and neural reward circuitry. Frontiers in Neuroscience, 6, 1–17. https://doi.org/10.3389/fnins.2012.00148

# %% [markdown]
# ### Python version

# %%
import sys
print(sys.version)
# Out:
# 3.11.0 (v3.11.0:deaf509e8f, Oct 24 2022, 14:43:23) [Clang 13.0.0 (clang-1300.0.29.30)]

# %% [markdown]
# ### Load modules

# %%
import numpy as np
import random
import math
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import itertools
import os
import csv

# %% [markdown]
# ## Pull in functions

# %%
run common_functions.ipynb

# %%
run double_alpha_functions.ipynb

# %% [markdown]
# ### Pull in parameters fit to Trustworthy/Untrustworthy conditions

# %%
pt = pd.read_csv('../../output/generalization_criterion/a2_fit2_2cond_part.csv')
pt.head(5)
# Out:
#          id  alpha_gain  alpha_loss          beta        llh
# 0  sub-2013    0.002731    0.002246  2.000000e+01  32.366876
# 1  sub-2007    0.247394    0.200707  3.039108e-01  35.884138
# 2  sub-2006    0.000000    0.000000  1.000000e-10  41.588831
# 3  sub-2012    0.050043    1.000000  3.805525e-01  32.662632
# 4  sub-2004    1.000000    0.088426  2.279855e+00  12.709590

# %% [markdown]
# ### Load and clean data

# %%
files = os.listdir('../../data/modeling')
files.remove('.DS_Store')
files.remove('missing')
#print(files)

# %%
n_part = len(files)
print('number of participants: ', n_part)
# Out:
# number of participants:  63

# %%
def load_and_clean(file):
    path = os.path.join('../../data/modeling', file)
    dt = pd.read_csv(path)
    # recode trial type into numbers for model
    def stims(trial_type):
        if trial_type == "Trustworthy":
            return 0
        elif trial_type == "Neutral":
            return 1
        elif trial_type == "Untrustworthy":
            return 2
    dt['Stim_Sequence'] = dt['trial_type'].apply(stims)
    # rename response_key to choice
    def choices(response_key):
        if response_key == 'None':
            return 0 
        else:
            return response_key  
    dt['Choice'] = dt['response_key'].apply(choices)
    dt['Choice'] = pd.to_numeric(dt['Choice'])
    # calculte the trustee response
    def resp(trial_earnings):
        if trial_earnings >= 12:
            return 1
        else:
            return 0
    dt['Trustee_Response'] = dt['trial_earnings'].apply(resp)
    data = dt[['Stim_Sequence','Choice', 'Trustee_Response']]
    # limit to neutral trials only
    data = data[data['Stim_Sequence'] == 1]
    data.reset_index(drop=True, inplace=True)
    return(data)

# %%
# data = load_and_clean(files[0])
# data.head(20) # should only have 15 trials

# %%
# create csv file
file = open('../../output/generalization_criterion/a2_llh4_1cond_part.csv', 'w')

# add header
headerList = ['id','a2_llh']
with open('../../output/generalization_criterion/a2_llh4_1cond_part.csv', 'a') as f_object: 
    dw = csv.DictWriter(f_object, delimiter = ',', fieldnames = headerList)
    dw.writeheader()

#loop thru participants
for x in range(n_part):
    print('loop:', x)
    subject = files[x][:-4]
    print(subject)
    
    # load and clean data
    print('loading data')
    data = load_and_clean(files[x])
    
    # pull parameters
    print('pull parameters')
    params = pt.loc[pt['id'] == subject].values.flatten().tolist()
    #print(params[1:4])
    
    # calculting llh
    print('calculating llh')
    llh = get_likelihood_action(params[1:4], data)
    a2 = [subject, llh]
    print(a2)
    
    # save results
    print('saving results')
    with open('../../output/generalization_criterion/a2_llh4_1cond_part.csv', 'a') as f_object: # create a file object
        writer_object = csv.writer(f_object) # pass the file object to csv writer
        writer_object.writerow(a2) #pass list as argument to writerow
        f_object.close() # close the file object
# Out:
# loop: 0
# sub-2013
# loading data
# pull parameters
# calculating llh
# ['sub-2013', 14.371683837121704]
# saving results
# loop: 1
# sub-2007
# loading data
# pull parameters
# calculating llh
# ['sub-2007', 15.708927587769018]
# saving results
# loop: 2
# sub-2006
# loading data
# pull parameters
# calculating llh
# ['sub-2006', 19.408121055678468]
# saving results
# loop: 3
# sub-2012
# loading data
# pull parameters
# calculating llh
# ['sub-2012', 15.013056383676123]
# saving results
# loop: 4
# sub-2004
# loading data
# pull parameters
# calculating llh
# ['sub-2004', 73.8832303728022]
# saving results
# loop: 5
# sub-2010
# loading data
# pull parameters
# calculating llh
# ['sub-2010', 20.783823024228585]
# saving results
# loop: 6
# sub-2038
# loading data
# pull parameters
# calculating llh
# ['sub-2038', 20.871048322060357]
# saving results
# loop: 7
# sub-2039
# loading data
# pull parameters
# calculating llh
# ['sub-2039', 1716.25849995194]
# saving results
# loop: 8
# sub-2011
# loading data
# pull parameters
# calculating llh
# ['sub-2011', 21.19645265691952]
# saving results
# loop: 9
# sub-2005
# loading data
# pull parameters
# calculating llh
# ['sub-2005', 21.299275986877323]
# saving results
# loop: 10
# sub-2001
# loading data
# pull parameters
# calculating llh
# ['sub-2001', 20.838117994343392]
# saving results
# loop: 11
# sub-2002
# loading data
# pull parameters
# calculating llh
# ['sub-2002', 21.032361539093365]
# saving results
# loop: 12
# sub-2003
# loading data
# pull parameters
# calculating llh
# ['sub-2003', 23.804958101730865]
# saving results
# loop: 13
# sub-1009
# loading data
# pull parameters
# calculating llh
# ['sub-1009', 19.92565646877974]
# saving results
# loop: 14
# sub-1021
# loading data
# pull parameters
# calculating llh
# ['sub-1021', 22.000193544892603]
# saving results
# loop: 15
# sub-1035
# loading data
# pull parameters
# calculating llh
# ['sub-1035', 13.410628462665642]
# saving results
# loop: 16
# sub-1034
# loading data
# pull parameters
# calculating llh
# ['sub-1034', 20.454234717481558]
# saving results
# loop: 17
# sub-1020
# loading data
# pull parameters
# calculating llh
# ['sub-1020', 16.64372596899579]
# saving results
# loop: 18
# sub-1008
# loading data
# pull parameters
# calculating llh
# ['sub-1008', 103.70302663163451]
# saving results
# loop: 19
# sub-1036
# loading data
# pull parameters
# calculating llh
# ['sub-1036', 8.543518964033865]
# saving results
# loop: 20
# sub-1022
# loading data
# pull parameters
# calculating llh
# ['sub-1022', 18.302594824081236]
# saving results
# loop: 21
# sub-1023
# loading data
# pull parameters
# calculating llh
# ['sub-1023', 26.923023707936483]
# saving results
# loop: 22
# sub-1037
# loading data
# pull parameters
# calculating llh
# ['sub-1037', 18.71991951535009]
# saving results
# loop: 23
# sub-1033
# loading data
# pull parameters
# calculating llh
# ['sub-1033', 24.40354839685216]
# saving results
# loop: 24
# sub-1026
# loading data
# pull parameters
# calculating llh
# ['sub-1026', 20.87229687670149]
# saving results
# loop: 25
# sub-1032
# loading data
# pull parameters
# calculating llh
# ['sub-1032', 16.086364432426166]
# saving results
# loop: 26
# sub-1024
# loading data
# pull parameters
# calculating llh
# ['sub-1024', 121.3862943611199]
# saving results
# loop: 27
# sub-1030
# loading data
# pull parameters
# calculating llh
# ['sub-1030', 11.41903753681651]
# saving results
# loop: 28
# sub-1018
# loading data
# pull parameters
# calculating llh
# ['sub-1018', 21.985208175895426]
# saving results
# loop: 29
# sub-1019
# loading data
# pull parameters
# calculating llh
# ['sub-1019', 12.96758255432369]
# saving results
# loop: 30
# sub-1025
# loading data
# pull parameters
# calculating llh
# ['sub-1025', 19.654865907107464]
# saving results
# loop: 31
# sub-1028
# loading data
# pull parameters
# calculating llh
# ['sub-1028', 19.75934580221482]
# saving results
# loop: 32
# sub-1014
# loading data
# pull parameters
# calculating llh
# ['sub-1014', 21.360584014402615]
# saving results
# loop: 33
# sub-1015
# loading data
# pull parameters
# calculating llh
# ['sub-1015', 10.743994110500742]
# saving results
# loop: 34
# sub-1029
# loading data
# pull parameters
# calculating llh
# ['sub-1029', 2147.8824587294325]
# saving results
# loop: 35
# sub-1017
# loading data
# pull parameters
# calculating llh
# ['sub-1017', 6.950759078157217]
# saving results
# loop: 36
# sub-1016
# loading data
# pull parameters
# calculating llh
# ['sub-1016', 19.487294107615075]
# saving results
# loop: 37
# sub-1012
# loading data
# pull parameters
# calculating llh
# ['sub-1012', 45.50441530438996]
# saving results
# loop: 38
# sub-1006
# loading data
# pull parameters
# calculating llh
# ['sub-1006', 21.40373027146791]
# saving results
# loop: 39
# sub-1007
# loading data
# pull parameters
# calculating llh
# ['sub-1007', 14.534542969311223]
# saving results
# loop: 40
# sub-1013
# loading data
# pull parameters
# calculating llh
# ['sub-1013', 22.019810967079103]
# saving results
# loop: 41
# sub-1005
# loading data
# pull parameters
# calculating llh
# ['sub-1005', 18.28699775113053]
# saving results
# loop: 42
# sub-1039
# loading data
# pull parameters
# calculating llh
# ['sub-1039', 993.7517356078263]
# saving results
# loop: 43
# sub-1038
# loading data
# pull parameters
# calculating llh
# ['sub-1038', 124.77942470426832]
# saving results
# loop: 44
# sub-1010
# loading data
# pull parameters
# calculating llh
# ['sub-1010', 18.94548357058046]
# saving results
# loop: 45
# sub-1004
# loading data
# pull parameters
# calculating llh
# ['sub-1004', 14.244427520091342]
# saving results
# loop: 46
# sub-2026
# loading data
# pull parameters
# calculating llh
# ['sub-2026', 7.482201290341049]
# saving results
# loop: 47
# sub-2027
# loading data
# pull parameters
# calculating llh
# ['sub-2027', 17.051867253084694]
# saving results
# loop: 48
# sub-2033
# loading data
# pull parameters
# calculating llh
# ['sub-2033', 21.468293443265395]
# saving results
# loop: 49
# sub-2025
# loading data
# pull parameters
# calculating llh
# ['sub-2025', 18.49159861378595]
# saving results
# loop: 50
# sub-2031
# loading data
# pull parameters
# calculating llh
# ['sub-2031', 20.854923428711444]
# saving results
# loop: 51
# sub-2019
# loading data
# pull parameters
# calculating llh
# ['sub-2019', 29.48375448305016]
# saving results
# loop: 52
# sub-2018
# loading data
# pull parameters
# calculating llh
# ['sub-2018', 65.59817380250684]
# saving results
# loop: 53
# sub-2030
# loading data
# pull parameters
# calculating llh
# ['sub-2030', 19.649548122896174]
# saving results
# loop: 54
# sub-2024
# loading data
# pull parameters
# calculating llh
# ['sub-2024', 27.376434207439342]
# saving results
# loop: 55
# sub-2020
# loading data
# pull parameters
# calculating llh
# ['sub-2020', 7.322772614322975]
# saving results
# loop: 56
# sub-2034
# loading data
# pull parameters
# calculating llh
# ['sub-2034', 1.3862943611198906]
# saving results
# loop: 57
# sub-2021
# loading data
# pull parameters
# calculating llh
# ['sub-2021', 27.33298045679908]
# saving results
# loop: 58
# sub-2009
# loading data
# pull parameters
# calculating llh
# ['sub-2009', 20.76055375957328]
# saving results
# loop: 59
# sub-2037
# loading data
# pull parameters
# calculating llh
# ['sub-2037', 18.07624489138551]
# saving results
# loop: 60
# sub-2023
# loading data
# pull parameters
# calculating llh
# ['sub-2023', 35.891946098497506]
# saving results
# loop: 61
# sub-2022
# loading data
# pull parameters
# calculating llh
# ['sub-2022', 19.416402904005878]
# saving results
# loop: 62
# sub-2036
# loading data
# pull parameters
# calculating llh
# ['sub-2036', 20.70813785570233]
# saving results
