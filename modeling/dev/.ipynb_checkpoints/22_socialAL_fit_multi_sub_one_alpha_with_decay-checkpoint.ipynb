# %% [markdown]
# # SocialAL Model
#
# ### Fit single alpha with decay model to data - multiple subjects
#
# KLS 3.3.22
# Project info: https://osf.io/b48n2/
#
# Model modified from : Fareri, D. S., Chang, L. J., & Delgado, M. R. (2012). Effects of direct social experience on trust decisions and neural reward circuitry. Frontiers in Neuroscience, 6, 1–17. https://doi.org/10.3389/fnins.2012.00148

# %%
import sys
print(sys.version)
import numpy as np
import random
import math
import pandas as pd
from scipy.optimize import minimize
import os
from decimal import *
# Out:
# 3.7.3 (default, Mar 27 2019, 16:54:48)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
def update_value(Prob):
    invest = [0,3,6,9]
    retain = [9-x for x in invest] #print ("Retain list is: ", retain)
    shared = [2*x for x in invest] #print ("Shared list is: ", shared)
    EV = [(retain[x] + Prob*shared[x]) for x in range(0,4)]
    return EV

def update_prob(recip, Prob, alpha):
    Prob = Prob + alpha*(recip-Prob)
    return Prob

def get_action_selection_prob(beta, EV, choice):
    actionProb = Decimal(np.exp(beta*EV[choice-1])/np.sum([np.exp(beta*x) for x in EV]))
    return actionProb

def get_action_selection_probs(beta, EV):
    actionProbs = [get_action_selection_prob(beta, EV, x) for x in range(1,5)]
    return actionProbs

def get_likelihood_action(params, data):
    alpha = params[0]
    beta = params[1]
    decay = params[2]
    
    # initialize variables
    prob = [0.5, 0.5, 0.5]
    ev = [[9,9,9,9],[9,9,9,9],[9,9,9,9]]
    
    totalLLH = 0 
    for trial in range(0, len(data)):
        trustee = data['Stim_Sequence'][trial] # get trustee type
        choice = data['Choice'][trial] # get choice made by participant
        response = data['Trustee_Response'][trial] # get response from trustee
        
        # compute the probability of selecting each option for that trustee
        probs = get_action_selection_probs(beta, ev[trustee])
        
        # use the probability of the selection (choice-probability) to update log likelihood
        if choice != 0:
            cprob = probs[choice-1] #print(cprob, isinstance(cprob, float))
            #print(cprob)

            #add to cumulative log likelihood
            totalLLH += -(math.log(cprob))
        
            # update prob and value
            if choice != 1:
                prob[trustee] = update_prob(response, prob[trustee], alpha)
            ev[trustee] = update_value(prob[trustee])
            
        # decay prob and value for other possible trustees 
        options = [0, 1, 2]
        if choice == 2 or choice == 3 or choice == 4:
            options.pop(trustee)
        for x in options:
            prob[x] = prob[x] + decay * (0.5 - prob[x])
            ev[x] =  update_value(prob[x])       
    return totalLLH

def model_fit_once(data):
        # initialize free parameters with randomly chosen numbers
        alpha=random.uniform(0, 1)
        beta=random.uniform(0, 1)
        decay=random.uniform(0,1)
        params = [alpha, beta, decay]
        
        #results = minimize(get_likelihood_action, 
                           #params, args =(data), method='BFGS', options = {'maxiter': 10000, 'disp': False})
        results = minimize(get_likelihood_action, 
                       params, args =(data), bounds = [(0, 1), (1e-10, 100), (0, 1)], 
                       options = {'maxiter': 10000, 'disp': False})
        return results

def model_fit(data):
    
    tries = 10000 #  number of tries to find the best-fit parameter
    lowestLLH = math.inf 
    bestFit = 'NA'
    
    for i in range(tries):
        
        # initialize free parameters with randomly chosen numbers
        alpha=random.uniform(0, 1)
        beta=random.uniform(0, 1)
        decay=random.uniform(0,1)
        params = [alpha, beta, decay]

        # trying different solvers in the minimize call...
        results = minimize(get_likelihood_action, 
                           params, args =(data), bounds = [(0, 1), (1e-10, 20), (0, 1)], 
                           options = {'maxiter': 10000, 'disp': False})
        if (lowestLLH > results['fun'] and results['success']== True):
            lowestLLH = results['fun']
            bestFit = results
            
    return bestFit

# %% [markdown]
# Load and Clean Data

# %%
files = os.listdir('../../data/modeling')

# %%
def load_and_clean(file):
    path = os.path.join('../../data/modeling', file)
    dt = pd.read_csv(path)
    # recode trial type into numbers for model
    def stims(trial_type):
        if trial_type == "Trustworthy":
            return 0
        elif trial_type == "Neutral":
            return 1
        elif trial_type == "Untrustworthy":
            return 2
    dt['Stim_Sequence'] = dt['trial_type'].apply(stims)
    # rename response_key to choice
    def choices(response_key):
        if response_key == 'None':
            return 0 
        else:
            return response_key  
    dt['Choice'] = dt['response_key'].apply(choices)
    dt['Choice'] = pd.to_numeric(dt['Choice'])
    # calculte the trustee response
    def resp(trial_earnings):
        if trial_earnings >= 12:
            return 1
        else:
            return 0
    dt['Trustee_Response'] = dt['trial_earnings'].apply(resp)
    data = dt[['Stim_Sequence','Choice', 'Trustee_Response']]
    return(data)

# %% [markdown]
# Fit Model

# %%
print(getcontext())
params = [model_fit(load_and_clean(file)) for file in files]
# Out:
# Context(prec=28, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[InvalidOperation, DivisionByZero, Overflow])

# %%
params
# Out:
# [      fun: 46.686237847491405
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 0.00336513, -0.00222897, -0.00010942])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 292
#        nit: 47
#     status: 0
#    success: True
#          x: array([4.41472043e-03, 2.00000000e+01, 3.22066747e-02]),
#        fun: 51.64479495954007
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-7.10542736e-07, -1.42108547e-06,  5.97529706e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 60
#        nit: 12
#     status: 0
#    success: True
#          x: array([0.21207537, 0.3359905 , 0.        ]),
#        fun: 60.99695188927512
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 8
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10, 1.e+00]),
#        fun: 61.447733727972405
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-4.43797887e-01,  2.13162821e-06, -1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 76
#        nit: 15
#     status: 0
#    success: True
#          x: array([1.        , 0.14993407, 0.62107598]),
#        fun: 35.03147962191212
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-6.39488462e-06, -2.84217094e-06,  5.82645043e-05])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 84
#        nit: 17
#     status: 0
#    success: True
#          x: array([0.17398434, 1.22419621, 0.01016293]),
#        fun: 59.61065752815523
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 8
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10, 1.e+00]),
#        fun: 60.99695188927512
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 8
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.00000000e+00, 1.00000000e-10, 9.74553014e-01]),
#        fun: 50.8549419859035
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 2.27373675e-05, -7.93676236e-04, -5.68434189e-06])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 260
#        nit: 51
#     status: 0
#    success: True
#          x: array([1.73950969e-02, 2.00000000e+01, 6.20404438e-01]),
#        fun: 59.37276244711443
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([1.37951766e+01, 9.32587341e-03, 1.06524638e+00])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 60
#        nit: 7
#     status: 0
#    success: True
#          x: array([3.23252191e-03, 4.67068173e+00, 9.23494317e-02]),
#        fun: 44.14021751572149
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-3.70928319e+00, -7.10542736e-07,  2.84217094e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 116
#        nit: 16
#     status: 0
#    success: True
#          x: array([1.        , 0.38447167, 0.07095788]),
#        fun: 60.99695188927512
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 4
#        nit: 0
#     status: 0
#    success: True
#          x: array([0.42024959, 0.69702506, 0.93320853]),
#        fun: 37.06816900516912
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([7.10542736e-07, 0.00000000e+00, 3.30837388e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 60
#        nit: 12
#     status: 0
#    success: True
#          x: array([0.48113683, 0.54726838, 0.        ]),
#        fun: 59.61065752815523
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 4
#        nit: 0
#     status: 0
#    success: True
#          x: array([0.43048667, 0.64859984, 0.18053772]),
#        fun: 61.63615912779208
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-3.49855611e-01, -7.10542736e-07,  7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 252
#        nit: 42
#     status: 0
#    success: True
#          x: array([1.        , 0.08479473, 0.28542266]),
#        fun: 55.884541791962825
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 1.47366563e-03, -5.79802872e-04,  2.84217094e-06])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 232
#        nit: 44
#     status: 0
#    success: True
#          x: array([5.20898274e-03, 2.00000000e+01, 3.80068365e-01]),
#        fun: 57.08992751906935
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 2.94186009e-02, -7.95807864e-05,  1.84897367e+01])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 444
#        nit: 84
#     status: 0
#    success: True
#          x: array([1.17454671e-03, 2.00000000e+01, 0.00000000e+00]),
#        fun: 36.12654425405006
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 2.84217094e-06,  4.26325641e-06, -9.94759830e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 128
#        nit: 20
#     status: 0
#    success: True
#          x: array([0.37989934, 0.64545105, 0.00334232]),
#        fun: 42.186211490265755
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([1.42108547e-06, 7.10542736e-07, 2.13162821e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 92
#        nit: 14
#     status: 0
#    success: True
#          x: array([0.57445159, 0.45976147, 0.03519605]),
#        fun: 37.615317494319015
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.84217094e-06, -7.10542736e-07, -4.26325641e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 76
#        nit: 14
#     status: 0
#    success: True
#          x: array([0.38851456, 0.72476988, 0.01630884]),
#        fun: 36.32769802447816
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 1.42108547e-06, -1.42108547e-06,  1.02160826e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 68
#        nit: 11
#     status: 0
#    success: True
#          x: array([0.76274191, 0.47769414, 0.        ]),
#        fun: 57.03176472860012
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([1.46371804e-04, 2.77111667e-05, 4.36133490e+01])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 112
#        nit: 16
#     status: 0
#    success: True
#          x: array([0.09842048, 0.50325988, 0.        ]),
#        fun: 39.97669344462991
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.13162821e-06,  7.10542736e-07, -3.55271368e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 92
#        nit: 17
#     status: 0
#    success: True
#          x: array([0.11488526, 1.82684755, 0.06464062]),
#        fun: 56.38975676039137
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 3.55271368e-06, -9.94759830e-06,  1.01517358e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 88
#        nit: 13
#     status: 0
#    success: True
#          x: array([0.89611885, 0.18219554, 0.        ]),
#        fun: 47.76170133257454
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 2.13162821e-06, -2.84217094e-06,  1.03421236e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 88
#        nit: 13
#     status: 0
#    success: True
#          x: array([0.62938295, 0.35162928, 0.        ]),
#        fun: 42.29688630896228
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-4.26325641e-06, -6.54409860e-04,  6.39488462e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 232
#        nit: 46
#     status: 0
#    success: True
#          x: array([ 0.05395429, 20.        ,  0.60089688]),
#        fun: 48.24280680750224
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([7.10542736e-07, 1.42108547e-06, 2.59866880e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 84
#        nit: 15
#     status: 0
#    success: True
#          x: array([0.75447095, 0.3019802 , 0.        ]),
#        fun: 61.05220814282749
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 0.00000000e+00,  1.42108547e-06, -2.09808491e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 96
#        nit: 16
#     status: 0
#    success: True
#          x: array([1.        , 0.13987254, 1.        ]),
#        fun: 59.91486092724666
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-1.36556366e-01,  2.13162821e-06,  5.71514391e-01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 64
#        nit: 12
#     status: 0
#    success: True
#          x: array([1.        , 0.06912119, 0.        ]),
#        fun: 57.78343038214099
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-6.82121026e-05, -7.38964445e-05,  9.23705556e-06])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 424
#        nit: 80
#     status: 0
#    success: True
#          x: array([9.17575389e-03, 2.00000000e+01, 6.89823303e-01]),
#        fun: 10.300203805771309
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([1.59872116e-06, 0.00000000e+00, 4.08365613e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 84
#        nit: 13
#     status: 0
#    success: True
#          x: array([0.56844737, 2.1625988 , 0.        ]),
#        fun: 36.4691135808296
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-6.87176183e+00,  2.84217094e-06,  3.41421512e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 84
#        nit: 14
#     status: 0
#    success: True
#          x: array([1.        , 0.42303646, 0.        ]),
#        fun: 54.585524132371866
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.91533553e-01,  5.68434189e-06,  5.15045713e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 112
#        nit: 16
#     status: 0
#    success: True
#          x: array([1.        , 0.19435666, 0.        ]),
#        fun: 37.26323911833465
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-7.10542736e-07, -1.42108547e-06,  5.28864327e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 72
#        nit: 11
#     status: 0
#    success: True
#          x: array([0.60051001, 0.53338993, 0.        ]),
#        fun: 41.37067735868262
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 0.        ,  0.        , 14.10594948])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 48
#        nit: 7
#     status: 0
#    success: True
#          x: array([0.31892519, 0.55008073, 0.        ]),
#        fun: 60.99695188927512
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 8
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10, 1.e+00]),
#        fun: 43.745894972549806
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-1.42108547e-06, -1.42108547e-06,  2.07124273e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 72
#        nit: 11
#     status: 0
#    success: True
#          x: array([0.27718302, 0.51517583, 0.        ]),
#        fun: 57.70398021899925
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-7.10542736e-07,  1.42108547e-06,  7.05898060e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 96
#        nit: 15
#     status: 0
#    success: True
#          x: array([0.10533948, 0.36753289, 0.        ]),
#        fun: 31.185805019592745
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-3.55271368e-07,  1.06581410e-06,  6.39488462e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 92
#        nit: 17
#     status: 0
#    success: True
#          x: array([0.78085241, 0.943265  , 0.10304843]),
#        fun: 38.58524309329351
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 7.88702437e-05, -3.52073926e-03, -6.39488462e-06])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 180
#        nit: 31
#     status: 0
#    success: True
#          x: array([ 0.02909594, 20.        ,  0.24530576]),
#        fun: 38.533725711929
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ -0.37232155,   0.        , 141.02396477])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 72
#        nit: 13
#     status: 0
#    success: True
#          x: array([1.        , 0.38186826, 0.        ]),
#        fun: 62.383246250395004
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 8
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10, 1.e+00]),
#        fun: 33.45833719362397
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 8.86046791e-04, -1.20792265e-03,  5.91775731e+00])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 276
#        nit: 48
#     status: 0
#    success: True
#          x: array([9.38250134e-03, 2.00000000e+01, 0.00000000e+00]),
#        fun: 55.70930567184492
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 0.00000000e+00, -7.10542736e-06,  2.11707416e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 56
#        nit: 11
#     status: 0
#    success: True
#          x: array([0.48866169, 0.16523716, 0.        ]),
#        fun: 39.16083889954759
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.84217094e-06, 1.42108547e-06, 2.48090487e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 48
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.68441491, 0.48068302, 0.        ]),
#        fun: 47.83642976145559
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.84217094e-06,  0.00000000e+00,  7.95224153e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 108
#        nit: 14
#     status: 0
#    success: True
#          x: array([0.49845993, 0.38644689, 0.        ]),
#        fun: 46.55177292856612
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-7.10542736e-07,  7.10542736e-07,  6.02880291e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 80
#        nit: 14
#     status: 0
#    success: True
#          x: array([0.34476384, 0.48415733, 0.        ]),
#        fun: 27.527882219366397
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([5.68434189e-06, 0.00000000e+00, 1.21743518e+01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 80
#        nit: 17
#     status: 0
#    success: True
#          x: array([0.15202581, 2.16517184, 0.        ]),
#        fun: 36.69864469089867
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([  0.        ,   0.        , 128.59452099])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 48
#        nit: 7
#     status: 0
#    success: True
#          x: array([0.6446465 , 0.58491093, 0.        ]),
#        fun: 46.5484948257216
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 2.13162821e-06,  4.97379915e-06, -9.94759830e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 116
#        nit: 22
#     status: 0
#    success: True
#          x: array([0.43251464, 0.52408052, 0.03537456]),
#        fun: 42.197014876939406
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-7.10542736e-07,  1.42108547e-06,  7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 84
#        nit: 17
#     status: 0
#    success: True
#          x: array([0.34765499, 0.59533523, 0.02925548]),
#        fun: 53.299065567711835
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.46031462e+00,  3.55271368e-06,  3.55271368e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 64
#        nit: 10
#     status: 0
#    success: True
#          x: array([1.        , 0.19058979, 0.01040609]),
#        fun: 41.83599559132662
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([1.42108547e-06, 2.13162821e-06, 1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 92
#        nit: 16
#     status: 0
#    success: True
#          x: array([0.59785238, 0.5231342 , 0.07340846]),
#        fun: 49.88052050332299
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-1.96427408e-01,  0.00000000e+00, -7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 112
#        nit: 19
#     status: 0
#    success: True
#          x: array([1.        , 0.16370146, 0.12707652]),
#        fun: 36.836868829686125
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-8.32488851e+00, -2.13162821e-06,  1.22024422e+02])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 112
#        nit: 14
#     status: 0
#    success: True
#          x: array([1.        , 0.45632739, 0.        ]),
#        fun: 62.22266130449203
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-4.83524332e-02, -1.42108547e-06, -3.22347660e-01])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 64
#        nit: 8
#     status: 0
#    success: True
#          x: array([1.        , 0.05372486, 1.        ])]

# %%
params = pd.DataFrame(params)
params['id'] = [file[:-4] for file in files]
params['alpha'] = [params['x'][y][0] for y in range(len(params))]
params['beta'] = [params['x'][y][1] for y in range(len(params))]
params['decay'] = [params['x'][y][2] for y in range(len(params))]
params['-LLH'] = [params['fun'][y] for y in range(len(params))]
params = params[['id', 'alpha', 'beta', 'decay', '-LLH']]
print(params)
# Out:
#           id     alpha          beta     decay       -LLH
# 0   sub-2013  0.004415  2.000000e+01  0.032207  46.686238
# 1   sub-2007  0.212075  3.359905e-01  0.000000  51.644795
# 2   sub-2006  0.000000  1.000000e-10  1.000000  60.996952
# 3   sub-2012  1.000000  1.499341e-01  0.621076  61.447734
# 4   sub-2004  0.173984  1.224196e+00  0.010163  35.031480
# 5   sub-2010  0.000000  1.000000e-10  1.000000  59.610658
# 6   sub-1040  0.000000  1.000000e-10  0.974553  60.996952
# 7   sub-2011  0.017395  2.000000e+01  0.620404  50.854942
# 8   sub-2005  0.003233  4.670682e+00  0.092349  59.372762
# 9   sub-2001  1.000000  3.844717e-01  0.070958  44.140218
# 10  sub-2015  0.420250  6.970251e-01  0.933209  60.996952
# 11  sub-2014  0.481137  5.472684e-01  0.000000  37.068169
# 12  sub-2016  0.430487  6.485998e-01  0.180538  59.610658
# 13  sub-2002  1.000000  8.479473e-02  0.285423  61.636159
# 14  sub-2003  0.005209  2.000000e+01  0.380068  55.884542
# 15  sub-1009  0.001175  2.000000e+01  0.000000  57.089928
# 16  sub-1021  0.379899  6.454511e-01  0.003342  36.126544
# 17  sub-1035  0.574452  4.597615e-01  0.035196  42.186211
# 18  sub-1034  0.388515  7.247699e-01  0.016309  37.615317
# 19  sub-1020  0.762742  4.776941e-01  0.000000  36.327698
# 20  sub-1008  0.098420  5.032599e-01  0.000000  57.031765
# 21  sub-1036  0.114885  1.826848e+00  0.064641  39.976693
# 22  sub-1022  0.896119  1.821955e-01  0.000000  56.389757
# 23  sub-1023  0.629383  3.516293e-01  0.000000  47.761701
# 24  sub-1037  0.053954  2.000000e+01  0.600897  42.296886
# 25  sub-1033  0.754471  3.019802e-01  0.000000  48.242807
# 26  sub-1027  1.000000  1.398725e-01  1.000000  61.052208
# 27  sub-1026  1.000000  6.912119e-02  0.000000  59.914861
# 28  sub-1032  0.009176  2.000000e+01  0.689823  57.783430
# 29  sub-1024  0.568447  2.162599e+00  0.000000  10.300204
# 30  sub-1030  1.000000  4.230365e-01  0.000000  36.469114
# 31  sub-1018  1.000000  1.943567e-01  0.000000  54.585524
# 32  sub-1019  0.600510  5.333899e-01  0.000000  37.263239
# 33  sub-1031  0.318925  5.500807e-01  0.000000  41.370677
# 34  sub-1025  0.000000  1.000000e-10  1.000000  60.996952
# 35  sub-1028  0.277183  5.151758e-01  0.000000  43.745895
# 36  sub-1014  0.105339  3.675329e-01  0.000000  57.703980
# 37  sub-1015  0.780852  9.432650e-01  0.103048  31.185805
# 38  sub-1029  0.029096  2.000000e+01  0.245306  38.585243
# 39  sub-1017  1.000000  3.818683e-01  0.000000  38.533726
# 40  sub-1016  0.000000  1.000000e-10  1.000000  62.383246
# 41  sub-1012  0.009383  2.000000e+01  0.000000  33.458337
# 42  sub-1006  0.488662  1.652372e-01  0.000000  55.709306
# 43  sub-1007  0.684415  4.806830e-01  0.000000  39.160839
# 44  sub-1013  0.498460  3.864469e-01  0.000000  47.836430
# 45  sub-1005  0.344764  4.841573e-01  0.000000  46.551773
# 46  sub-1039  0.152026  2.165172e+00  0.000000  27.527882
# 47  sub-1038  0.644646  5.849109e-01  0.000000  36.698645
# 48  sub-1010  0.432515  5.240805e-01  0.035375  46.548495
# 49  sub-1004  0.347655  5.953352e-01  0.029255  42.197015
# 50  sub-2019  1.000000  1.905898e-01  0.010406  53.299066
# 51  sub-2018  0.597852  5.231342e-01  0.073408  41.835996
# 52  sub-2008  1.000000  1.637015e-01  0.127077  49.880521
# 53  sub-2020  1.000000  4.563274e-01  0.000000  36.836869
# 54  sub-2009  1.000000  5.372486e-02  1.000000  62.222661

# %%
# save parameters in text file
params.to_csv(path_or_buf = '../../output/single_alpha_with_decay_model_params.csv', index = False)
