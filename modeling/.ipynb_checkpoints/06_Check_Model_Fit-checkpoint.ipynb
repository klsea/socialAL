# %% [markdown]
# #SocialAL Model
# #generate trial-by-trial output from model fits
#
# KLS 2.7.20
# Project info: https://osf.io/b48n2/
#
# Model modified from : Fareri, D. S., Chang, L. J., & Delgado, M. R. (2012). Effects of direct social experience on trust decisions and neural reward circuitry. Frontiers in Neuroscience, 6, 1–17. https://doi.org/10.3389/fnins.2012.00148

# %% [markdown]
# Python version and modules

# %%
import sys
print(sys.version)  
import numpy as np
import random
import math
import pandas as pd
from scipy.optimize import minimize
import os
from decimal import *
# Out:
# 3.7.4 (default, Aug 13 2019, 15:17:50)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %% [markdown]
# Define Functions

# %%
def update_value(Prob):
    invest = [0,3,6,9]
    retain = [9-x for x in invest] #print ("Retain list is: ", retain)
    shared = [2*x for x in invest] #print ("Shared list is: ", shared)
    EV = [(retain[x] + Prob*shared[x]) for x in range(0,4)]
    return EV

def update_prob(recip, Prob, a_gain, a_loss):
    gain = max(recip - Prob, 0)
    loss = min(recip - Prob, 0)
    Prob = Prob + a_gain * gain + a_loss * loss
    return Prob

def get_action_selection_prob(beta, EV, choice):
    actionProb = Decimal(np.exp(beta*EV[choice-1])/np.sum([np.exp(beta*x) for x in EV]))
    return actionProb

def get_action_selection_probs(beta, EV):
    actionProbs = [get_action_selection_prob(beta, EV, x) for x in range(1,5)]
    return actionProbs

def get_likelihood_action(params, data):
    a_gain = params[0]
    a_loss = params[1]
    beta = params[2]
    
    # initialize variables
    prob = [0.5, 0.5, 0.5]
    ev = [[9,9,9,9],[9,9,9,9],[9,9,9,9]]
    tletters = ["A", "B", "C"]
    
    totalLLH = 0 
    for trial in range(0, len(data)):
        trustee = data['Stim_Sequence'][trial] # get trustee type
        choice = data['Choice'][trial] # get choice made by participant
        response = data['Trustee_Response'][trial] # get response from trustee
        
        # compute the probability of selecting each option for that trustee
        probs = get_action_selection_probs(beta, ev[trustee])
        
        if choice != 0:
            # use the probability of the selection (choice-probability) to update log likelihood
            cprob = probs[choice-1] #print(cprob, isinstance(cprob, float))
            #add to cumulative log likelihood
            totalLLH += -(math.log(cprob))
            

            # update prob and value
            if choice != 1:
                prob[trustee] = update_prob(response, prob[trustee], a_gain, a_loss)
            ev[trustee] = update_value(prob[trustee])
            
        #print("Trial #: ", trial + 1)
        #print("Trustee: ", tletters[trustee])
        print('LLH: ', totalLLH)
        #print('Trustee Prob: ', prob[trustee])
        #print('Trustee Expected values: ', ev[trustee])
        
    return totalLLH

def model_fit_once(data, param):
        # initialize free parameters with randomly chosen numbers
        a_gain=param[0]
        a_loss=param[1]
        beta=param[2]
        params = [a_gain, a_loss, beta]
        
        #results = minimize(get_likelihood_action, 
                           #params, args =(data), method='BFGS', options = {'maxiter': 10000, 'disp': False})
        results = minimize(get_likelihood_action, 
                       params, args =(data), bounds = [(0, 1), (0, 1), (1e-10, 100)], 
                       options = {'maxiter': 10000, 'disp': False})
        return results

# %% [markdown]
# Get data

# %%
#dt = pd.read_csv('../data/modeling/sub-1004.csv')
#dt = pd.read_csv('../data/modeling/sub-1008.csv') #- try getting this sub to work
dt = pd.read_csv('../data/modeling/sub-2032.csv') #- try getting this sub to work
# recode trial type into numbers for model
def stims(trial_type):
    if trial_type == "Trustworthy":
        return 0
    elif trial_type == "Neutral":
        return 1
    elif trial_type == "Untrustworthy":
        return 2
dt['Stim_Sequence'] = dt['trial_type'].apply(stims)
# rename response_key to choice
def choices(response_key):
    if response_key == 'None':
        return 0 
    else:
        return response_key  
dt['Choice'] = dt['response_key'].apply(choices)
dt['Choice'] = pd.to_numeric(dt['Choice'])
# calculte the trustee response
def resp(trial_earnings):
    if trial_earnings >= 12:
        return 1
    else:
        return 0
dt['Trustee_Response'] = dt['trial_earnings'].apply(resp)
data = dt[['Stim_Sequence','Choice', 'Trustee_Response']]
#print(data)

# %% [markdown]
# Input parameters

# %%
array = [ 0.49695529,  0.        ,  0.10735091, 54.29839312]

# %%
model_fit_once(data, array)
# Out:
# Trial #:  1
# Trustee:  B
# Trial #:  2
# Trustee:  A
# LLH:  1.3862943611198906
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  3
# Trustee:  A
# Trial #:  4
# Trustee:  B
# LLH:  2.772588722239781
# Trustee Prob:  0.748477645
# Trustee Expected values:  [9.0, 10.49086587, 11.98173174, 13.472597610000001]
# Trial #:  5
# Trustee:  A
# LLH:  4.1588830833596715
# Trustee Prob:  0.748477645
# Trustee Expected values:  [9.0, 10.49086587, 11.98173174, 13.472597610000001]
# Trial #:  6
# Trustee:  C
# LLH:  5.545177444479562
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  7
# Trustee:  B
# LLH:  7.027446155658433
# Trustee Prob:  0.8734730098705079
# Trustee Expected values:  [9.0, 11.240838059223048, 13.481676118446096, 15.722514177669142]
# Trial #:  8
# Trustee:  B
# Trial #:  9
# Trustee:  A
# LLH:  8.509714866837305
# Trustee Prob:  0.8734730098705079
# Trustee Expected values:  [9.0, 11.240838059223048, 13.481676118446096, 15.722514177669142]
# Trial #:  10
# Trustee:  C
# LLH:  9.896009227957196
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  11
# Trustee:  B
# LLH:  11.438456393314572
# Trustee Prob:  0.8734730098705079
# Trustee Expected values:  [9.0, 11.240838059223048, 13.481676118446096, 15.722514177669142]
# Trial #:  12
# Trustee:  B
# LLH:  12.740347553851722
# Trustee Prob:  0.8734730098705079
# Trustee Expected values:  [9.0, 11.240838059223048, 13.481676118446096, 15.722514177669142]
# Trial #:  13
# Trustee:  C
# LLH:  14.126641914971612
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  14
# Trustee:  B
# LLH:  15.428533075508762
# Trustee Prob:  0.9363512669431368
# Trustee Expected values:  [9.0, 11.61810760165882, 14.236215203317641, 16.854322804976462]
# Trial #:  15
# Trustee:  C
# LLH:  16.81482743662865
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  16
# Trustee:  A
# LLH:  17.876162592345572
# Trustee Prob:  0.9363512669431368
# Trustee Expected values:  [9.0, 11.61810760165882, 14.236215203317641, 16.854322804976462]
# Trial #:  17
# Trustee:  A
# Trial #:  18
# Trustee:  B
# LLH:  18.889701364441503
# Trustee Prob:  0.9679818415375429
# Trustee Expected values:  [9.0, 11.807891049225258, 14.615782098450515, 17.42367314767577]
# Trial #:  19
# Trustee:  A
# LLH:  20.74640883708541
# Trustee Expected values:  [9.0, 11.61810760165882, 14.236215203317641, 16.854322804976462]
# Trial #:  20
# Trustee:  C
# LLH:  22.132703198205302
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  21
# Trustee:  B
# LLH:  23.122925994200234
# Trustee Prob:  0.9838934347615192
# Trustee Expected values:  [9.0, 11.903360608569116, 14.80672121713823, 17.710081825707345]
# Trial #:  22
# Trustee:  C
# LLH:  24.509220355320124
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  23
# Trustee:  A
# LLH:  26.08487159444804
# Trustee Prob:  0.9679818415375429
# Trustee Expected values:  [9.0, 11.807891049225258, 14.615782098450515, 17.42367314767577]
# Trial #:  24
# Trustee:  B
# LLH:  27.06354754368398
# Trustee Prob:  0.9918976775605124
# Trustee Expected values:  [9.0, 11.951386065363074, 14.902772130726149, 17.854158196089223]
# Trial #:  25
# Trustee:  C
# Trial #:  26
# Trustee:  A
# LLH:  28.053770339678913
# Trustee Prob:  0.9838934347615192
# Trustee Expected values:  [9.0, 11.903360608569116, 14.80672121713823, 17.710081825707345]
# Trial #:  27
# Trustee:  A
# LLH:  29.344124692302906
# Trustee Prob:  0.9918976775605124
# Trustee Expected values:  [9.0, 11.951386065363074, 14.902772130726149, 17.854158196089223]
# Trial #:  28
# Trustee:  C
# LLH:  30.730419053422796
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  29
# Trustee:  B
# LLH:  31.7033322400074
# Trustee Prob:  0.9918976775605124
# Trustee Expected values:  [9.0, 11.951386065363074, 14.902772130726149, 17.854158196089223]
# Trial #:  30
# Trustee:  C
# LLH:  33.089626601127286
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  31
# Trustee:  C
# LLH:  34.47592096224717
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  32
# Trustee:  A
# LLH:  35.44883414883177
# Trustee Prob:  0.9959241695581015
# Trustee Expected values:  [9.0, 11.975545017348608, 14.951090034697218, 17.926635052045828]
# Trial #:  33
# Trustee:  C
# LLH:  36.83512850995166
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  34
# Trustee:  C
# LLH:  38.221422871071546
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  35
# Trustee:  B
# LLH:  39.82800401741224
# Trustee Prob:  0.9959241695581015
# Trustee Expected values:  [9.0, 11.975545017348608, 14.951090034697218, 17.926635052045828]
# Trial #:  36
# Trustee:  B
# LLH:  40.79802983562016
# Trustee Prob:  0.997949675057346
# Trustee Expected values:  [9.0, 11.987698050344076, 14.975396100688151, 17.963094151032227]
# Trial #:  37
# Trustee:  C
# LLH:  42.18432419674005
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  38
# Trustee:  A
# LLH:  43.47377748030631
# Trustee Prob:  0.997949675057346
# Trustee Expected values:  [9.0, 11.987698050344076, 14.975396100688151, 17.963094151032227]
# Trial #:  39
# Trustee:  C
# LLH:  44.8600718414262
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  40
# Trustee:  A
# LLH:  46.14938020921787
# Trustee Prob:  0.9989685948838168
# Trustee Expected values:  [9.0, 11.9938115693029, 14.987623138605802, 17.981434707908704]
# Trial #:  41
# Trustee:  B
# LLH:  47.438688577009536
# Trustee Prob:  0.997949675057346
# Trustee Expected values:  [9.0, 11.987698050344076, 14.975396100688151, 17.963094151032227]
# Trial #:  42
# Trustee:  A
# LLH:  49.37070157680428
# Trustee Expected values:  [9.0, 11.9938115693029, 14.987623138605802, 17.981434707908704]
# Trial #:  43
# Trustee:  B
# LLH:  51.301474153615274
# Trustee Expected values:  [9.0, 11.987698050344076, 14.975396100688151, 17.963094151032227]
# Trial #:  44
# Trustee:  A
# LLH:  52.912098757076826
# Trustee Prob:  0.9994811571124371
# Trustee Expected values:  [9.0, 11.996886942674623, 14.993773885349245, 17.99066082802387]
# Trial #:  45
# Trustee:  C
# LLH:  54.298393118196714
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  1
# Trustee:  B
# Trial #:  2
# Trustee:  A
# LLH:  1.3862943611198906
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  3
# Trustee:  A
# Trial #:  4
# Trustee:  B
# LLH:  2.772588722239781
# Trustee Prob:  0.74847765
# Trustee Expected values:  [9.0, 10.4908659, 11.9817318, 13.4725977]
# Trial #:  5
# Trustee:  A
# LLH:  4.1588830833596715
# Trustee Prob:  0.74847765
# Trustee Expected values:  [9.0, 10.4908659, 11.9817318, 13.4725977]
# Trial #:  6
# Trustee:  C
# LLH:  5.545177444479562
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  7
# Trustee:  B
# LLH:  7.027446157908356
# Trustee Prob:  0.873473014900955
# Trustee Expected values:  [9.0, 11.240838089405731, 13.48167617881146, 15.72251426821719]
# Trial #:  8
# Trustee:  B
# Trial #:  9
# Trustee:  A
# LLH:  8.50971487133715
# Trustee Prob:  0.873473014900955
# Trustee Expected values:  [9.0, 11.240838089405731, 13.48167617881146, 15.72251426821719]
# Trial #:  10
# Trustee:  C
# LLH:  9.896009232457041
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  11
# Trustee:  B
# LLH:  11.438456400393152
# Trustee Prob:  0.873473014900955
# Trustee Expected values:  [9.0, 11.240838089405731, 13.48167617881146, 15.72251426821719]
# Trial #:  12
# Trustee:  B
# LLH:  12.740347560268896
# Trustee Prob:  0.873473014900955
# Trustee Expected values:  [9.0, 11.240838089405731, 13.48167617881146, 15.72251426821719]
# Trial #:  13
# Trustee:  C
# LLH:  14.126641921388787
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  14
# Trustee:  B
# LLH:  15.428533081264531
# Trustee Prob:  0.9363512707389464
# Trustee Expected values:  [9.0, 11.618107624433678, 14.236215248867357, 16.854322873301037]
# Trial #:  15
# Trustee:  C
# LLH:  16.81482744238442
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  16
# Trustee:  A
# LLH:  17.876162594199798
# Trustee Prob:  0.9363512707389464
# Trustee Expected values:  [9.0, 11.618107624433678, 14.236215248867357, 16.854322873301037]
# Trial #:  17
# Trustee:  A
# Trial #:  18
# Trustee:  B
# LLH:  18.88970136346866
# Trustee Prob:  0.9679818440834921
# Trustee Expected values:  [9.0, 11.807891064500954, 14.615782129001905, 17.423673193502857]
# Trial #:  19
# Trustee:  A
# LLH:  20.7464088406202
# Trustee Expected values:  [9.0, 11.618107624433678, 14.236215248867357, 16.854322873301037]
# Trial #:  20
# Trustee:  C
# LLH:  22.132703201740092
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  21
# Trustee:  B
# LLH:  23.12292599587774
# Trustee Prob:  0.9838934363624271
# Trustee Expected values:  [9.0, 11.903360618174563, 14.806721236349125, 17.710081854523686]
# Trial #:  22
# Trustee:  C
# LLH:  24.50922035699763
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  23
# Trustee:  A
# LLH:  26.08487159818828
# Trustee Prob:  0.9679818440834921
# Trustee Expected values:  [9.0, 11.807891064500954, 14.615782129001905, 17.423673193502857]
# Trial #:  24
# Trustee:  B
# LLH:  27.063547546268566
# Trustee Prob:  0.9918976785269062
# Trustee Expected values:  [9.0, 11.951386071161437, 14.902772142322874, 17.85415821348431]
# Trial #:  25
# Trustee:  C
# Trial #:  26
# Trustee:  A
# LLH:  28.053770340406214
# Trustee Prob:  0.9838934363624271
# Trustee Expected values:  [9.0, 11.903360618174563, 14.806721236349125, 17.710081854523686]
# Trial #:  27
# Trustee:  A
# LLH:  29.3441246929057
# Trustee Prob:  0.9918976785269062
# Trustee Expected values:  [9.0, 11.951386071161437, 14.902772142322874, 17.85415821348431]
# Trial #:  28
# Trustee:  C
# LLH:  30.730419054025592
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  29
# Trustee:  B
# LLH:  31.70333223991627
# Trustee Prob:  0.9918976785269062
# Trustee Expected values:  [9.0, 11.951386071161437, 14.902772142322874, 17.85415821348431]
# Trial #:  30
# Trustee:  C
# LLH:  33.08962660103616
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  31
# Trustee:  C
# LLH:  34.475920962156046
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  32
# Trustee:  A
# LLH:  35.44883414804672
# Trustee Prob:  0.995924170125264
# Trustee Expected values:  [9.0, 11.975545020751584, 14.951090041503168, 17.926635062254753]
# Trial #:  33
# Trustee:  C
# LLH:  36.83512850916661
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  34
# Trustee:  C
# LLH:  38.221422870286496
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  35
# Trustee:  B
# LLH:  39.82800401717819
# Trustee Prob:  0.995924170125264
# Trustee Expected values:  [9.0, 11.975545020751584, 14.951090041503168, 17.926635062254753]
# Trial #:  36
# Trustee:  B
# LLH:  40.79802983497994
# Trustee Prob:  0.9979496753834124
# Trustee Expected values:  [9.0, 11.987698052300473, 14.975396104600948, 17.963094156901423]
# Trial #:  37
# Trustee:  C
# LLH:  42.18432419609983
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  38
# Trustee:  A
# LLH:  43.47377747962524
# Trustee Prob:  0.9979496753834124
# Trustee Expected values:  [9.0, 11.987698052300473, 14.975396104600948, 17.963094156901423]
# Trial #:  39
# Trustee:  C
# LLH:  44.86007184074513
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  40
# Trustee:  A
# LLH:  46.14938020851363
# Trustee Prob:  0.9989685950683461
# Trustee Expected values:  [9.0, 11.993811570410077, 14.987623140820153, 17.98143471123023]
# Trial #:  41
# Trustee:  B
# LLH:  47.438688576282125
# Trustee Prob:  0.9979496753834124
# Trustee Expected values:  [9.0, 11.987698052300473, 14.975396104600948, 17.963094156901423]
# Trial #:  42
# Trustee:  A
# LLH:  49.370701576301556
# Trustee Expected values:  [9.0, 11.993811570410077, 14.987623140820153, 17.98143471123023]
# Trial #:  43
# Trustee:  B
# LLH:  51.30147415350942
# Trustee Expected values:  [9.0, 11.987698052300473, 14.975396104600948, 17.963094156901423]
# Trial #:  44
# Trustee:  A
# LLH:  52.9120987570768
# Trustee Prob:  0.9994811572155776
# Trustee Expected values:  [9.0, 11.996886943293465, 14.993773886586931, 17.990660829880397]
# Trial #:  45
# Trustee:  C
# LLH:  54.298393118196685
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  1
# Trustee:  B
# Trial #:  2
# Trustee:  A
# LLH:  1.3862943611198906
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  3
# Trustee:  A
# Trial #:  4
# Trustee:  B
# LLH:  2.772588722239781
# Trustee Prob:  0.748477645
# Trustee Expected values:  [9.0, 10.49086587, 11.98173174, 13.472597610000001]
# Trial #:  5
# Trustee:  A
# LLH:  4.1588830833596715
# Trustee Prob:  0.748477645
# Trustee Expected values:  [9.0, 10.49086587, 11.98173174, 13.472597610000001]
# Trial #:  6
# Trustee:  C
# LLH:  5.545177444479562
# Trustee Prob:  0.499999995
# Trustee Expected values:  [9.0, 8.99999997, 8.999999939999999, 8.99999991]
# Trial #:  7
# Trustee:  B
# LLH:  7.027446155658433
# Trustee Prob:  0.8734730098705079
# Trustee Expected values:  [9.0, 11.240838059223048, 13.481676118446096, 15.722514177669142]
# Trial #:  8
# Trustee:  B
# Trial #:  9
# Trustee:  A
# LLH:  8.509714866837305
# Trustee Prob:  0.8734730098705079
# Trustee Expected values:  [9.0, 11.240838059223048, 13.481676118446096, 15.722514177669142]
# Trial #:  10
# Trustee:  C
# LLH:  9.896009226346932
# Trustee Prob:  0.49999999
# Trustee Expected values:  [9.0, 8.99999994, 8.99999988, 8.99999982]
# Trial #:  11
# Trustee:  B
# LLH:  11.438456391704309
# Trustee Prob:  0.8734730011357779
# Trustee Expected values:  [9.0, 11.240838006814666, 13.481676013629334, 15.722514020444002]
# Trial #:  12
# Trustee:  B
# LLH:  12.740347553389903
# Trustee Prob:  0.8734729924010478
# Trustee Expected values:  [9.0, 11.240837954406286, 13.481675908812573, 15.722513863218861]
# Trial #:  13
# Trustee:  C
# LLH:  14.126641911289266
# Trustee Prob:  0.4999999850000001
# Trustee Expected values:  [9.0, 8.99999991, 8.999999820000001, 8.999999730000003]
# Trial #:  14
# Trustee:  B
# LLH:  15.428533074123305
# Trustee Prob:  0.9363512581552174
# Trustee Expected values:  [9.0, 11.618107548931304, 14.236215097862608, 16.85432264679391]
# Trial #:  15
# Trustee:  C
# LLH:  16.814827449735567
# Trustee Prob:  0.49999998000000023
# Trustee Expected values:  [9.0, 8.99999988, 8.999999760000003, 8.999999640000004]
# Trial #:  16
# Trustee:  A
# LLH:  17.87616260545249
# Trustee Prob:  0.9363512669431368
# Trustee Expected values:  [9.0, 11.61810760165882, 14.236215203317641, 16.854322804976462]
# Trial #:  17
# Trustee:  A
# Trial #:  18
# Trustee:  B
# LLH:  18.889701384093552
# Trustee Prob:  0.9679818371168265
# Trustee Expected values:  [9.0, 11.807891022700959, 14.615782045401918, 17.42367306810288]
# Trial #:  19
# Trustee:  A
# LLH:  20.74640885673746
# Trustee Expected values:  [9.0, 11.61810760165882, 14.236215203317641, 16.854322804976462]
# Trial #:  20
# Trustee:  C
# LLH:  22.132703211416295
# Trustee Prob:  0.49999997500000043
# Trustee Expected values:  [9.0, 8.999999850000002, 8.999999700000005, 8.999999550000007]
# Trial #:  21
# Trustee:  B
# LLH:  23.122926010636167
# Trustee Prob:  0.9838934325377012
# Trustee Expected values:  [9.0, 11.903360595226207, 14.806721190452414, 17.71008178567862]
# Trial #:  22
# Trustee:  C
# LLH:  24.509220395910013
# Trustee Prob:  0.4999999700000007
# Trustee Expected values:  [9.0, 8.999999820000005, 8.99999964000001, 8.999999460000012]
# Trial #:  23
# Trustee:  A
# LLH:  26.084871635037928
# Trustee Prob:  0.9679818415375429
# Trustee Expected values:  [9.0, 11.807891049225258, 14.615782098450515, 17.42367314767577]
# Trial #:  24
# Trustee:  B
# LLH:  27.063547585879192
# Trustee Prob:  0.9918976764418325
# Trustee Expected values:  [9.0, 11.951386058650995, 14.90277211730199, 17.854158175952985]
# Trial #:  25
# Trustee:  C
# Trial #:  26
# Trustee:  A
# LLH:  28.053770381874124
# Trustee Prob:  0.9838934347615192
# Trustee Expected values:  [9.0, 11.903360608569116, 14.80672121713823, 17.710081825707345]
# Trial #:  27
# Trustee:  A
# LLH:  29.344124734498116
# Trustee Prob:  0.9918976775605124
# Trustee Expected values:  [9.0, 11.951386065363074, 14.902772130726149, 17.854158196089223]
# Trial #:  28
# Trustee:  C
# LLH:  30.730419124602754
# Trustee Prob:  0.499999965000001
# Trustee Expected values:  [9.0, 8.999999790000006, 8.999999580000011, 8.999999370000017]
# Trial #:  29
# Trustee:  B
# LLH:  31.703332311990625
# Trustee Prob:  0.9918976665228557
# Trustee Expected values:  [9.0, 11.951385999137134, 14.902771998274268, 17.854157997411402]
# Trial #:  30
# Trustee:  C
# LLH:  33.08962666183867
# Trustee Prob:  0.49999996000000135
# Trustee Expected values:  [9.0, 8.999999760000009, 8.999999520000017, 8.999999280000024]
# Trial #:  31
# Trustee:  C
# LLH:  34.47592103584067
# Trustee Prob:  0.4999999550000018
# Trustee Expected values:  [9.0, 8.99999973000001, 8.999999460000021, 8.999999190000032]
# Trial #:  32
# Trustee:  A
# LLH:  35.44883422242527
# Trustee Prob:  0.9959241695581015
# Trustee Expected values:  [9.0, 11.975545017348608, 14.951090034697218, 17.926635052045828]
# Trial #:  33
# Trustee:  C
# LLH:  36.835128598037535
# Trustee Prob:  0.49999995000000225
# Trustee Expected values:  [9.0, 8.999999700000014, 8.999999400000027, 8.999999100000041]
# Trial #:  34
# Trustee:  C
# LLH:  38.22142294305479
# Trustee Prob:  0.4999999450000027
# Trustee Expected values:  [9.0, 8.999999670000015, 8.999999340000032, 8.99999901000005]
# Trial #:  35
# Trustee:  B
# LLH:  39.82800408310227
# Trustee Prob:  0.9959241640056666
# Trustee Expected values:  [9.0, 11.975544984034, 14.951089968068, 17.926634952102]
# Trial #:  36
# Trustee:  B
# LLH:  40.79802990528648
# Trustee Prob:  0.997949672264223
# Trustee Expected values:  [9.0, 11.987698033585339, 14.975396067170676, 17.963094100756013]
# Trial #:  37
# Trustee:  C
# LLH:  42.18432431954506
# Trustee Prob:  0.49999994000000325
# Trustee Expected values:  [9.0, 8.99999964000002, 8.99999928000004, 8.999998920000058]
# Trial #:  38
# Trustee:  A
# LLH:  43.47377760311132
# Trustee Prob:  0.997949675057346
# Trustee Expected values:  [9.0, 11.987698050344076, 14.975396100688151, 17.963094151032227]
# Trial #:  39
# Trustee:  C
# LLH:  44.86007194490805
# Trustee Prob:  0.49999993500000384
# Trustee Expected values:  [9.0, 8.999999610000023, 8.999999220000046, 8.999998830000068]
# Trial #:  40
# Trustee:  A
# LLH:  46.14938031269972
# Trustee Prob:  0.9989685948838168
# Trustee Expected values:  [9.0, 11.9938115693029, 14.987623138605802, 17.981434707908704]
# Trial #:  41
# Trustee:  B
# LLH:  47.43868868068988
# Trustee Prob:  0.9979496622847264
# Trustee Expected values:  [9.0, 11.987697973708357, 14.975395947416716, 17.963093921125076]
# Trial #:  42
# Trustee:  A
# LLH:  49.37070168048462
# Trustee Expected values:  [9.0, 11.9938115693029, 14.987623138605802, 17.981434707908704]
# Trial #:  43
# Trustee:  B
# LLH:  51.30147424174945
# Trustee Expected values:  [9.0, 11.987697973708357, 14.975395947416716, 17.963093921125076]
# Trial #:  44
# Trustee:  A
# LLH:  52.912098845211005
# Trustee Prob:  0.9994811571124371
# Trustee Expected values:  [9.0, 11.996886942674623, 14.993773885349245, 17.99066082802387]
# Trial #:  45
# Trustee:  C
# LLH:  54.29839314353062
# Trustee Expected values:  [9.0, 8.999999610000023, 8.999999220000046, 8.999998830000068]
# Trial #:  1
# Trustee:  B
# Trial #:  2
# Trustee:  A
# LLH:  1.3862943611198906
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  3
# Trustee:  A
# Trial #:  4
# Trustee:  B
# LLH:  2.772588722239781
# Trustee Prob:  0.748477645
# Trustee Expected values:  [9.0, 10.49086587, 11.98173174, 13.472597610000001]
# Trial #:  5
# Trustee:  A
# LLH:  4.1588830833596715
# Trustee Prob:  0.748477645
# Trustee Expected values:  [9.0, 10.49086587, 11.98173174, 13.472597610000001]
# Trial #:  6
# Trustee:  C
# LLH:  5.545177444479562
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  7
# Trustee:  B
# LLH:  7.027446166073912
# Trustee Prob:  0.8734730098705079
# Trustee Expected values:  [9.0, 11.240838059223048, 13.481676118446096, 15.722514177669142]
# Trial #:  8
# Trustee:  B
# Trial #:  9
# Trustee:  A
# LLH:  8.509714887668261
# Trustee Prob:  0.8734730098705079
# Trustee Expected values:  [9.0, 11.240838059223048, 13.481676118446096, 15.722514177669142]
# Trial #:  10
# Trustee:  C
# LLH:  9.896009248788152
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  11
# Trustee:  B
# LLH:  11.43845643197972
# Trustee Prob:  0.8734730098705079
# Trustee Expected values:  [9.0, 11.240838059223048, 13.481676118446096, 15.722514177669142]
# Trial #:  12
# Trustee:  B
# LLH:  12.74034758794268
# Trustee Prob:  0.8734730098705079
# Trustee Expected values:  [9.0, 11.240838059223048, 13.481676118446096, 15.722514177669142]
# Trial #:  13
# Trustee:  C
# LLH:  14.12664194906257
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  14
# Trustee:  B
# LLH:  15.42853310502553
# Trustee Prob:  0.9363512669431368
# Trustee Expected values:  [9.0, 11.61810760165882, 14.236215203317641, 16.854322804976462]
# Trial #:  15
# Trustee:  C
# LLH:  16.81482746614542
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  16
# Trustee:  A
# LLH:  17.876162594879773
# Trustee Prob:  0.9363512669431368
# Trustee Expected values:  [9.0, 11.61810760165882, 14.236215203317641, 16.854322804976462]
# Trial #:  17
# Trustee:  A
# Trial #:  18
# Trustee:  B
# LLH:  18.8897013367022
# Trustee Prob:  0.9679818415375429
# Trustee Expected values:  [9.0, 11.807891049225258, 14.615782098450515, 17.42367314767577]
# Trial #:  19
# Trustee:  A
# LLH:  20.74640885761583
# Trustee Expected values:  [9.0, 11.61810760165882, 14.236215203317641, 16.854322804976462]
# Trial #:  20
# Trustee:  C
# LLH:  22.13270321873572
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  21
# Trustee:  B
# LLH:  23.122925982928827
# Trustee Prob:  0.9838934347615192
# Trustee Expected values:  [9.0, 11.903360608569116, 14.80672121713823, 17.710081825707345]
# Trial #:  22
# Trustee:  C
# LLH:  24.509220344048718
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  23
# Trustee:  A
# LLH:  26.08487160526528
# Trustee Prob:  0.9679818415375429
# Trustee Expected values:  [9.0, 11.807891049225258, 14.615782098450515, 17.42367314767577]
# Trial #:  24
# Trustee:  B
# LLH:  27.063547521962047
# Trustee Prob:  0.9918976775605124
# Trustee Expected values:  [9.0, 11.951386065363074, 14.902772130726149, 17.854158196089223]
# Trial #:  25
# Trustee:  C
# Trial #:  26
# Trustee:  A
# LLH:  28.053770286155153
# Trustee Prob:  0.9838934347615192
# Trustee Expected values:  [9.0, 11.903360608569116, 14.80672121713823, 17.710081825707345]
# Trial #:  27
# Trustee:  A
# LLH:  29.344124635273573
# Trustee Prob:  0.9918976775605124
# Trustee Expected values:  [9.0, 11.951386065363074, 14.902772130726149, 17.854158196089223]
# Trial #:  28
# Trustee:  C
# LLH:  30.730418996393464
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  29
# Trustee:  B
# LLH:  31.70333215007583
# Trustee Prob:  0.9918976775605124
# Trustee Expected values:  [9.0, 11.951386065363074, 14.902772130726149, 17.854158196089223]
# Trial #:  30
# Trustee:  C
# LLH:  33.08962651119572
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  31
# Trustee:  C
# LLH:  34.475920872315605
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  32
# Trustee:  A
# LLH:  35.448834025997975
# Trustee Prob:  0.9959241695581015
# Trustee Expected values:  [9.0, 11.975545017348608, 14.951090034697218, 17.926635052045828]
# Trial #:  33
# Trustee:  C
# LLH:  36.83512838711786
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  34
# Trustee:  C
# LLH:  38.22142274823775
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  35
# Trustee:  B
# LLH:  39.82800392070393
# Trustee Prob:  0.9959241695581015
# Trustee Expected values:  [9.0, 11.975545017348608, 14.951090034697218, 17.926635052045828]
# Trial #:  36
# Trustee:  B
# LLH:  40.79802970582897
# Trustee Prob:  0.997949675057346
# Trustee Expected values:  [9.0, 11.987698050344076, 14.975396100688151, 17.963094151032227]
# Trial #:  37
# Trustee:  C
# LLH:  42.184324066948854
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  38
# Trustee:  A
# LLH:  43.47377734718768
# Trustee Prob:  0.997949675057346
# Trustee Expected values:  [9.0, 11.987698050344076, 14.975396100688151, 17.963094151032227]
# Trial #:  39
# Trustee:  C
# LLH:  44.860071708307565
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  40
# Trustee:  A
# LLH:  46.14938007280295
# Trustee Prob:  0.9989685948838168
# Trustee Expected values:  [9.0, 11.9938115693029, 14.987623138605802, 17.981434707908704]
# Trial #:  41
# Trustee:  B
# LLH:  47.43868843729833
# Trustee Prob:  0.997949675057346
# Trustee Expected values:  [9.0, 11.987698050344076, 14.975396100688151, 17.963094151032227]
# Trial #:  42
# Trustee:  A
# LLH:  49.37070149368882
# Trustee Expected values:  [9.0, 11.9938115693029, 14.987623138605802, 17.981434707908704]
# Trial #:  43
# Trustee:  B
# LLH:  51.30147412695749
# Trustee Expected values:  [9.0, 11.987698050344076, 14.975396100688151, 17.963094151032227]
# Trial #:  44
# Trustee:  A
# LLH:  52.91209875707666
# Trustee Prob:  0.9994811571124371
# Trustee Expected values:  [9.0, 11.996886942674623, 14.993773885349245, 17.99066082802387]
# Trial #:  45
# Trustee:  C
# LLH:  54.29839311819655
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  1
# Trustee:  B
# Trial #:  2
# Trustee:  A
# LLH:  1.3862943611198906
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  3
# Trustee:  A
# Trial #:  4
# Trustee:  B
# LLH:  2.772588722239781
# Trustee Prob:  0.7484790660854715
# Trustee Expected values:  [9.0, 10.49087439651283, 11.981748793025659, 13.472623189538488]
# Trial #:  5
# Trustee:  A
# LLH:  4.1588830833596715
# Trustee Prob:  0.7484790660854715
# Trustee Expected values:  [9.0, 10.49087439651283, 11.981748793025659, 13.472623189538488]
# Trial #:  6
# Trustee:  C
# LLH:  5.545177444479562
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  7
# Trustee:  B
# LLH:  7.027463817091201
# Trustee Prob:  0.8734744396055268
# Trustee Expected values:  [9.0, 11.240846637633162, 13.481693275266322, 15.722539912899483]
# Trial #:  8
# Trustee:  B
# Trial #:  9
# Trustee:  A
# LLH:  8.509750189702839
# Trustee Prob:  0.8734744396055268
# Trustee Expected values:  [9.0, 11.240846637633162, 13.481693275266322, 15.722539912899483]
# Trial #:  10
# Trustee:  C
# LLH:  9.89604455082273
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  11
# Trustee:  B
# LLH:  11.438521595546419
# Trustee Prob:  0.8734744396055268
# Trustee Expected values:  [9.0, 11.240846637633162, 13.481693275266322, 15.722539912899483]
# Trial #:  12
# Trustee:  B
# LLH:  12.740405093551841
# Trustee Prob:  0.8734744396055268
# Trustee Expected values:  [9.0, 11.240846637633162, 13.481693275266322, 15.722539912899483]
# Trial #:  13
# Trustee:  C
# LLH:  14.126699454671732
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  14
# Trustee:  B
# LLH:  15.428582952677154
# Trustee Prob:  0.9363523457710461
# Trustee Expected values:  [9.0, 11.618114074626277, 14.236228149252554, 16.85434222387883]
# Trial #:  15
# Trustee:  C
# LLH:  16.814877313797044
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  16
# Trustee:  A
# LLH:  17.8761672650842
# Trustee Prob:  0.9363523457710461
# Trustee Expected values:  [9.0, 11.618114074626277, 14.236228149252554, 16.85434222387883]
# Trial #:  17
# Trustee:  A
# Trial #:  18
# Trustee:  B
# LLH:  18.889655760243045
# Trustee Prob:  0.967982565133729
# Trustee Expected values:  [9.0, 11.807895390802374, 14.615790781604748, 17.423686172407123]
# Trial #:  19
# Trustee:  A
# LLH:  20.74644340004037
# Trustee Expected values:  [9.0, 11.618114074626277, 14.236228149252554, 16.85434222387883]
# Trial #:  20
# Trustee:  C
# LLH:  22.13273776116026
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  21
# Trustee:  B
# LLH:  23.122908058371255
# Trustee Prob:  0.9838938897617759
# Trustee Expected values:  [9.0, 11.903363338570657, 14.806726677141311, 17.710090015711966]
# Trial #:  22
# Trustee:  C
# LLH:  24.509202419491146
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  23
# Trustee:  A
# LLH:  26.08489034440898
# Trustee Prob:  0.967982565133729
# Trustee Expected values:  [9.0, 11.807895390802374, 14.615790781604748, 17.423686172407123]
# Trial #:  24
# Trustee:  B
# LLH:  27.063512789358448
# Trustee Prob:  0.991897952222303
# Trustee Expected values:  [9.0, 11.951387713333819, 14.902775426667636, 17.854163140001454]
# Trial #:  25
# Trustee:  C
# Trial #:  26
# Trustee:  A
# LLH:  28.053683086569443
# Trustee Prob:  0.9838938897617759
# Trustee Expected values:  [9.0, 11.903363338570657, 14.806726677141311, 17.710090015711966]
# Trial #:  27
# Trustee:  A
# LLH:  29.344031676140887
# Trustee Prob:  0.991897952222303
# Trustee Expected values:  [9.0, 11.951387713333819, 14.902775426667636, 17.854163140001454]
# Trial #:  28
# Trustee:  C
# LLH:  30.730326037260777
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  29
# Trustee:  B
# LLH:  31.703185257523057
# Trustee Prob:  0.991897952222303
# Trustee Expected values:  [9.0, 11.951387713333819, 14.902775426667636, 17.854163140001454]
# Trial #:  30
# Trustee:  C
# LLH:  33.08947961864295
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  31
# Trustee:  C
# LLH:  34.475773979762835
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  32
# Trustee:  A
# LLH:  35.448633200025114
# Trustee Prob:  0.9959243307526671
# Trustee Expected values:  [9.0, 11.975545984516003, 14.951091969032005, 17.926637953548006]
# Trial #:  33
# Trustee:  C
# LLH:  36.834927561145
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  34
# Trustee:  C
# LLH:  38.22122192226489
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  35
# Trustee:  B
# LLH:  39.82784592211218
# Trustee Prob:  0.9959243307526671
# Trustee Expected values:  [9.0, 11.975545984516003, 14.951091969032005, 17.926637953548006]
# Trial #:  36
# Trustee:  B
# LLH:  40.79781756057683
# Trustee Prob:  0.9979497677291682
# Trustee Expected values:  [9.0, 11.987698606375009, 14.975397212750018, 17.963095819125027]
# Trial #:  37
# Trustee:  C
# LLH:  42.18411192169672
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  38
# Trustee:  A
# LLH:  43.47355975715544
# Trustee Prob:  0.9979497677291682
# Trustee Expected values:  [9.0, 11.987698606375009, 14.975397212750018, 17.963095819125027]
# Trial #:  39
# Trustee:  C
# LLH:  44.85985411827533
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  40
# Trustee:  A
# LLH:  46.14915709390299
# Trustee Prob:  0.9989686473289974
# Trustee Expected values:  [9.0, 11.993811883973985, 14.98762376794797, 17.981435651921952]
# Trial #:  41
# Trustee:  B
# LLH:  47.438460069530656
# Trustee Prob:  0.9979497677291682
# Trustee Expected values:  [9.0, 11.987698606375009, 14.975397212750018, 17.963095819125027]
# Trial #:  42
# Trustee:  A
# LLH:  49.3705656260653
# Trustee Expected values:  [9.0, 11.993811883973985, 14.98762376794797, 17.981435651921952]
# Trial #:  43
# Trustee:  B
# LLH:  51.30143058292005
# Trustee Expected values:  [9.0, 11.987698606375009, 14.975397212750018, 17.963095819125027]
# Trial #:  44
# Trustee:  A
# LLH:  52.91209878302168
# Trustee Prob:  0.9994811864259884
# Trustee Expected values:  [9.0, 11.99688711855593, 14.993774237111861, 17.99066135566779]
# Trial #:  45
# Trustee:  C
# LLH:  54.29839314414157
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  1
# Trustee:  B
# Trial #:  2
# Trustee:  A
# LLH:  1.3862943611198906
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  3
# Trustee:  A
# Trial #:  4
# Trustee:  B
# LLH:  2.772588722239781
# Trustee Prob:  0.7484790710854715
# Trustee Expected values:  [9.0, 10.490874426512828, 11.981748853025659, 13.472623279538487]
# Trial #:  5
# Trustee:  A
# LLH:  4.1588830833596715
# Trustee Prob:  0.7484790710854715
# Trustee Expected values:  [9.0, 10.490874426512828, 11.981748853025659, 13.472623279538487]
# Trial #:  6
# Trustee:  C
# LLH:  5.545177444479562
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  7
# Trustee:  B
# LLH:  7.027463819341565
# Trustee Prob:  0.8734744446359454
# Trustee Expected values:  [9.0, 11.240846667815672, 13.481693335631345, 15.722540003447017]
# Trial #:  8
# Trustee:  B
# Trial #:  9
# Trustee:  A
# LLH:  8.50975019420357
# Trustee Prob:  0.8734744446359454
# Trustee Expected values:  [9.0, 11.240846667815672, 13.481693335631345, 15.722540003447017]
# Trial #:  10
# Trustee:  C
# LLH:  9.89604455532346
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  11
# Trustee:  B
# LLH:  11.438521602626405
# Trustee Prob:  0.8734744446359454
# Trustee Expected values:  [9.0, 11.240846667815672, 13.481693335631345, 15.722540003447017]
# Trial #:  12
# Trustee:  B
# LLH:  12.74040509997047
# Trustee Prob:  0.8734744446359454
# Trustee Expected values:  [9.0, 11.240846667815672, 13.481693335631345, 15.722540003447017]
# Trial #:  13
# Trustee:  C
# LLH:  14.126699461090361
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  14
# Trustee:  B
# LLH:  15.428582958434426
# Trustee Prob:  0.9363523495668128
# Trustee Expected values:  [9.0, 11.618114097400877, 14.236228194801754, 16.85434229220263]
# Trial #:  15
# Trustee:  C
# LLH:  16.814877319554316
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  16
# Trustee:  A
# LLH:  17.8761672669395
# Trustee Prob:  0.9363523495668128
# Trustee Expected values:  [9.0, 11.618114097400877, 14.236228194801754, 16.85434229220263]
# Trial #:  17
# Trustee:  A
# Trial #:  18
# Trustee:  B
# LLH:  18.889655759271
# Trustee Prob:  0.9679825676796351
# Trustee Expected values:  [9.0, 11.807895406077812, 14.615790812155621, 17.42368621823343]
# Trial #:  19
# Trustee:  A
# LLH:  20.74644340357672
# Trustee Expected values:  [9.0, 11.618114097400877, 14.236228194801754, 16.85434229220263]
# Trial #:  20
# Trustee:  C
# LLH:  22.13273776469661
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  21
# Trustee:  B
# LLH:  23.122908060050158
# Trustee Prob:  0.9838938913626475
# Trustee Expected values:  [9.0, 11.903363348175885, 14.80672669635177, 17.710090044527654]
# Trial #:  22
# Trustee:  C
# LLH:  24.50920242117005
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  23
# Trustee:  A
# LLH:  26.084890348151028
# Trustee Prob:  0.9679825676796351
# Trustee Expected values:  [9.0, 11.807895406077812, 14.615790812155621, 17.42368621823343]
# Trial #:  24
# Trustee:  B
# LLH:  27.063512791944746
# Trustee Prob:  0.9918979531886696
# Trustee Expected values:  [9.0, 11.951387719132018, 14.902775438264035, 17.85416315739605]
# Trial #:  25
# Trustee:  C
# Trial #:  26
# Trustee:  A
# LLH:  28.053683087298293
# Trustee Prob:  0.9838938913626475
# Trustee Expected values:  [9.0, 11.903363348175885, 14.80672669635177, 17.710090044527654]
# Trial #:  27
# Trustee:  A
# LLH:  29.344031676745274
# Trustee Prob:  0.9918979531886696
# Trustee Expected values:  [9.0, 11.951387719132018, 14.902775438264035, 17.85416315739605]
# Trial #:  28
# Trustee:  C
# LLH:  30.730326037865165
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  29
# Trustee:  B
# LLH:  31.70318525743347
# Trustee Prob:  0.9918979531886696
# Trustee Expected values:  [9.0, 11.951387719132018, 14.902775438264035, 17.85416315739605]
# Trial #:  30
# Trustee:  C
# LLH:  33.08947961855336
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  31
# Trustee:  C
# LLH:  34.47577397967325
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  32
# Trustee:  A
# LLH:  35.448633199241556
# Trustee Prob:  0.9959243313198104
# Trustee Expected values:  [9.0, 11.975545987918863, 14.951091975837725, 17.926637963756587]
# Trial #:  33
# Trustee:  C
# LLH:  36.83492756036144
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  34
# Trustee:  C
# LLH:  38.22122192148133
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  35
# Trustee:  B
# LLH:  39.82784592187972
# Trustee Prob:  0.9959243313198104
# Trustee Expected values:  [9.0, 11.975545987918863, 14.951091975837725, 17.926637963756587]
# Trial #:  36
# Trustee:  B
# LLH:  40.797817559938174
# Trustee Prob:  0.9979497680552217
# Trustee Expected values:  [9.0, 11.98769860833133, 14.97539721666266, 17.963095824993992]
# Trial #:  37
# Trustee:  C
# LLH:  42.18411192105806
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  38
# Trustee:  A
# LLH:  43.47355975647595
# Trustee Prob:  0.9979497680552217
# Trustee Expected values:  [9.0, 11.98769860833133, 14.97539721666266, 17.963095824993992]
# Trial #:  39
# Trustee:  C
# LLH:  44.85985411759584
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  40
# Trustee:  A
# LLH:  46.14915709320034
# Trustee Prob:  0.9989686475135182
# Trustee Expected values:  [9.0, 11.99381188508111, 14.98762377016222, 17.981435655243327]
# Trial #:  41
# Trustee:  B
# LLH:  47.43846006880484
# Trustee Prob:  0.9979497680552217
# Trustee Expected values:  [9.0, 11.98769860833133, 14.97539721666266, 17.963095824993992]
# Trial #:  42
# Trustee:  A
# LLH:  49.3705656255642
# Trustee Expected values:  [9.0, 11.99381188508111, 14.98762377016222, 17.981435655243327]
# Trial #:  43
# Trustee:  B
# LLH:  51.30143058281587
# Trustee Expected values:  [9.0, 11.98769860833133, 14.97539721666266, 17.963095824993992]
# Trial #:  44
# Trustee:  A
# LLH:  52.91209878302335
# Trustee Prob:  0.9994811865291235
# Trustee Expected values:  [9.0, 11.99688711917474, 14.993774238349483, 17.990661357524225]
# Trial #:  45
# Trustee:  C
# LLH:  54.29839314414324
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  1
# Trustee:  B
# Trial #:  2
# Trustee:  A
# LLH:  1.3862943611198906
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  3
# Trustee:  A
# Trial #:  4
# Trustee:  B
# LLH:  2.772588722239781
# Trustee Prob:  0.7484790660854715
# Trustee Expected values:  [9.0, 10.49087439651283, 11.981748793025659, 13.472623189538488]
# Trial #:  5
# Trustee:  A
# LLH:  4.1588830833596715
# Trustee Prob:  0.7484790660854715
# Trustee Expected values:  [9.0, 10.49087439651283, 11.981748793025659, 13.472623189538488]
# Trial #:  6
# Trustee:  C
# LLH:  5.545177444479562
# Trustee Prob:  0.499999995
# Trustee Expected values:  [9.0, 8.99999997, 8.999999939999999, 8.99999991]
# Trial #:  7
# Trustee:  B
# LLH:  7.027463817091201
# Trustee Prob:  0.8734744396055268
# Trustee Expected values:  [9.0, 11.240846637633162, 13.481693275266322, 15.722539912899483]
# Trial #:  8
# Trustee:  B
# Trial #:  9
# Trustee:  A
# LLH:  8.509750189702839
# Trustee Prob:  0.8734744396055268
# Trustee Expected values:  [9.0, 11.240846637633162, 13.481693275266322, 15.722539912899483]
# Trial #:  10
# Trustee:  C
# LLH:  9.89604454921222
# Trustee Prob:  0.49999999
# Trustee Expected values:  [9.0, 8.99999994, 8.99999988, 8.99999982]
# Trial #:  11
# Trustee:  B
# LLH:  11.43852159393591
# Trustee Prob:  0.8734744308707825
# Trustee Expected values:  [9.0, 11.240846585224695, 13.48169317044939, 15.722539755674084]
# Trial #:  12
# Trustee:  B
# LLH:  12.740405093089702
# Trustee Prob:  0.8734744221360382
# Trustee Expected values:  [9.0, 11.24084653281623, 13.48169306563246, 15.722539598448687]
# Trial #:  13
# Trustee:  C
# LLH:  14.126699450988575
# Trustee Prob:  0.4999999850000001
# Trustee Expected values:  [9.0, 8.99999991, 8.999999820000001, 8.999999730000003]
# Trial #:  14
# Trustee:  B
# LLH:  15.428582951290737
# Trustee Prob:  0.9363523369831619
# Trustee Expected values:  [9.0, 11.618114021898972, 14.236228043797944, 16.854342065696915]
# Trial #:  15
# Trustee:  C
# LLH:  16.814877326905208
# Trustee Prob:  0.49999998000000023
# Trustee Expected values:  [9.0, 8.99999988, 8.999999760000003, 8.999999640000004]
# Trial #:  16
# Trustee:  A
# LLH:  17.876167278192362
# Trustee Prob:  0.9363523457710461
# Trustee Expected values:  [9.0, 11.618114074626277, 14.236228149252554, 16.85434222387883]
# Trial #:  17
# Trustee:  A
# Trial #:  18
# Trustee:  B
# LLH:  18.88965577989702
# Trustee Prob:  0.9679825607130553
# Trustee Expected values:  [9.0, 11.807895364278332, 14.615790728556664, 17.423686092834995]
# Trial #:  19
# Trustee:  A
# LLH:  20.746443419694344
# Trustee Expected values:  [9.0, 11.618114074626277, 14.236228149252554, 16.85434222387883]
# Trial #:  20
# Trustee:  C
# LLH:  22.1327377743722
# Trustee Prob:  0.49999997500000043
# Trustee Expected values:  [9.0, 8.999999850000002, 8.999999700000005, 8.999999550000007]
# Trial #:  21
# Trustee:  B
# LLH:  23.12290807480844
# Trustee Prob:  0.9838938875379919
# Trustee Expected values:  [9.0, 11.903363325227952, 14.806726650455904, 17.710089975683854]
# Trial #:  22
# Trustee:  C
# LLH:  24.509202460085962
# Trustee Prob:  0.4999999700000007
# Trustee Expected values:  [9.0, 8.999999820000005, 8.99999964000001, 8.999999460000012]
# Trial #:  23
# Trustee:  A
# LLH:  26.084890385003796
# Trustee Prob:  0.967982565133729
# Trustee Expected values:  [9.0, 11.807895390802374, 14.615790781604748, 17.423686172407123]
# Trial #:  24
# Trustee:  B
# LLH:  27.063512831558725
# Trustee Prob:  0.9918979511036465
# Trustee Expected values:  [9.0, 11.95138770662188, 14.90277541324376, 17.85416311986564]
# Trial #:  25
# Trustee:  C
# Trial #:  26
# Trustee:  A
# LLH:  28.05368312876972
# Trustee Prob:  0.9838938897617759
# Trustee Expected values:  [9.0, 11.903363338570657, 14.806726677141311, 17.710090015711966]
# Trial #:  27
# Trustee:  A
# LLH:  29.344031718341164
# Trustee Prob:  0.991897952222303
# Trustee Expected values:  [9.0, 11.951387713333819, 14.902775426667636, 17.854163140001454]
# Trial #:  28
# Trustee:  C
# LLH:  30.730326108450214
# Trustee Prob:  0.499999965000001
# Trustee Expected values:  [9.0, 8.999999790000006, 8.999999580000011, 8.999999370000017]
# Trial #:  29
# Trustee:  B
# LLH:  31.70318532951583
# Trustee Prob:  0.991897941184667
# Trustee Expected values:  [9.0, 11.951387647108003, 14.902775294216005, 17.854162941324006]
# Trial #:  30
# Trustee:  C
# LLH:  33.08947967936216
# Trustee Prob:  0.49999996000000135
# Trustee Expected values:  [9.0, 8.999999760000009, 8.999999520000017, 8.999999280000024]
# Trial #:  31
# Trustee:  C
# LLH:  34.475774053366116
# Trustee Prob:  0.4999999550000018
# Trustee Expected values:  [9.0, 8.99999973000001, 8.999999460000021, 8.999999190000032]
# Trial #:  32
# Trustee:  A
# LLH:  35.448633273628396
# Trustee Prob:  0.9959243307526671
# Trustee Expected values:  [9.0, 11.975545984516003, 14.951091969032005, 17.926637953548006]
# Trial #:  33
# Trustee:  C
# LLH:  36.834927649242864
# Trustee Prob:  0.49999995000000225
# Trustee Expected values:  [9.0, 8.999999700000014, 8.999999400000027, 8.999999100000041]
# Trial #:  34
# Trustee:  C
# LLH:  38.22122199425767
# Trustee Prob:  0.4999999450000027
# Trustee Expected values:  [9.0, 8.999999670000015, 8.999999340000032, 8.99999901000005]
# Trial #:  35
# Trustee:  B
# LLH:  39.827845987810406
# Trustee Prob:  0.995924325200274
# Trustee Expected values:  [9.0, 11.975545951201644, 14.951091902403288, 17.92663785360493]
# Trial #:  36
# Trustee:  B
# LLH:  40.797817630251714
# Trustee Prob:  0.997949764936082
# Trustee Expected values:  [9.0, 11.987698589616492, 14.975397179232985, 17.963095768849477]
# Trial #:  37
# Trustee:  C
# LLH:  42.18411204451839
# Trustee Prob:  0.49999994000000325
# Trustee Expected values:  [9.0, 8.99999964000002, 8.99999928000004, 8.999998920000058]
# Trial #:  38
# Trustee:  A
# LLH:  43.47355987997712
# Trustee Prob:  0.9979497677291682
# Trustee Expected values:  [9.0, 11.987698606375009, 14.975397212750018, 17.963095819125027]
# Trial #:  39
# Trustee:  C
# LLH:  44.8598542217709
# Trustee Prob:  0.49999993500000384
# Trustee Expected values:  [9.0, 8.999999610000023, 8.999999220000046, 8.999998830000068]
# Trial #:  40
# Trustee:  A
# LLH:  46.149157197398566
# Trustee Prob:  0.9989686473289974
# Trustee Expected values:  [9.0, 11.993811883973985, 14.98762376794797, 17.981435651921952]
# Trial #:  41
# Trustee:  B
# LLH:  47.43846017322464
# Trustee Prob:  0.9979497549565843
# Trustee Expected values:  [9.0, 11.987698529739506, 14.975397059479011, 17.96309558921852]
# Trial #:  42
# Trustee:  A
# LLH:  49.370565729759285
# Trustee Expected values:  [9.0, 11.993811883973985, 14.98762376794797, 17.981435651921952]
# Trial #:  43
# Trustee:  B
# LLH:  51.30143067106508
# Trustee Expected values:  [9.0, 11.987698529739506, 14.975397059479011, 17.96309558921852]
# Trial #:  44
# Trustee:  A
# LLH:  52.91209887116671
# Trustee Prob:  0.9994811864259884
# Trustee Expected values:  [9.0, 11.99688711855593, 14.993774237111861, 17.99066135566779]
# Trial #:  45
# Trustee:  C
# LLH:  54.29839316947677
# Trustee Expected values:  [9.0, 8.999999610000023, 8.999999220000046, 8.999998830000068]
# Trial #:  1
# Trustee:  B
# Trial #:  2
# Trustee:  A
# LLH:  1.3862943611198906
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  3
# Trustee:  A
# Trial #:  4
# Trustee:  B
# LLH:  2.772588722239781
# Trustee Prob:  0.7484790660854715
# Trustee Expected values:  [9.0, 10.49087439651283, 11.981748793025659, 13.472623189538488]
# Trial #:  5
# Trustee:  A
# LLH:  4.1588830833596715
# Trustee Prob:  0.7484790660854715
# Trustee Expected values:  [9.0, 10.49087439651283, 11.981748793025659, 13.472623189538488]
# Trial #:  6
# Trustee:  C
# LLH:  5.545177444479562
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  7
# Trustee:  B
# LLH:  7.0274638275072
# Trustee Prob:  0.8734744396055268
# Trustee Expected values:  [9.0, 11.240846637633162, 13.481693275266322, 15.722539912899483]
# Trial #:  8
# Trustee:  B
# Trial #:  9
# Trustee:  A
# LLH:  8.509750210534838
# Trustee Prob:  0.8734744396055268
# Trustee Expected values:  [9.0, 11.240846637633162, 13.481693275266322, 15.722539912899483]
# Trial #:  10
# Trustee:  C
# LLH:  9.896044571654729
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  11
# Trustee:  B
# LLH:  11.43852163421368
# Trustee Prob:  0.8734744396055268
# Trustee Expected values:  [9.0, 11.240846637633162, 13.481693275266322, 15.722539912899483]
# Trial #:  12
# Trustee:  B
# LLH:  12.740405127645898
# Trustee Prob:  0.8734744396055268
# Trustee Expected values:  [9.0, 11.240846637633162, 13.481693275266322, 15.722539912899483]
# Trial #:  13
# Trustee:  C
# LLH:  14.126699488765789
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  14
# Trustee:  B
# LLH:  15.428582982198007
# Trustee Prob:  0.9363523457710461
# Trustee Expected values:  [9.0, 11.618114074626277, 14.236228149252554, 16.85434222387883]
# Trial #:  15
# Trustee:  C
# LLH:  16.814877343317896
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  16
# Trustee:  A
# LLH:  17.87616726762338
# Trustee Prob:  0.9363523457710461
# Trustee Expected values:  [9.0, 11.618114074626277, 14.236228149252554, 16.85434222387883]
# Trial #:  17
# Trustee:  A
# Trial #:  18
# Trustee:  B
# LLH:  18.88965573250998
# Trustee Prob:  0.967982565133729
# Trustee Expected values:  [9.0, 11.807895390802374, 14.615790781604748, 17.423686172407123]
# Trial #:  19
# Trustee:  A
# LLH:  20.746443420578476
# Trustee Expected values:  [9.0, 11.618114074626277, 14.236228149252554, 16.85434222387883]
# Trial #:  20
# Trustee:  C
# LLH:  22.132737781698367
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  21
# Trustee:  B
# LLH:  23.122908047108996
# Trustee Prob:  0.9838938897617759
# Trustee Expected values:  [9.0, 11.903363338570657, 14.806726677141311, 17.710090015711966]
# Trial #:  22
# Trustee:  C
# LLH:  24.509202408228887
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  23
# Trustee:  A
# LLH:  26.08489035523675
# Trustee Prob:  0.967982565133729
# Trustee Expected values:  [9.0, 11.807895390802374, 14.615790781604748, 17.423686172407123]
# Trial #:  24
# Trustee:  B
# LLH:  27.06351276764861
# Trustee Prob:  0.991897952222303
# Trustee Expected values:  [9.0, 11.951387713333819, 14.902775426667636, 17.854163140001454]
# Trial #:  25
# Trustee:  C
# Trial #:  26
# Trustee:  A
# LLH:  28.05368303305924
# Trustee Prob:  0.9838938897617759
# Trustee Expected values:  [9.0, 11.903363338570657, 14.806726677141311, 17.710090015711966]
# Trial #:  27
# Trustee:  A
# LLH:  29.344031619126707
# Trustee Prob:  0.991897952222303
# Trustee Expected values:  [9.0, 11.951387713333819, 14.902775426667636, 17.854163140001454]
# Trial #:  28
# Trustee:  C
# LLH:  30.730325980246597
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  29
# Trustee:  B
# LLH:  31.703185167608268
# Trustee Prob:  0.991897952222303
# Trustee Expected values:  [9.0, 11.951387713333819, 14.902775426667636, 17.854163140001454]
# Trial #:  30
# Trustee:  C
# LLH:  33.089479528728155
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  31
# Trustee:  C
# LLH:  34.47577388984804
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  32
# Trustee:  A
# LLH:  35.44863307720971
# Trustee Prob:  0.9959243307526671
# Trustee Expected values:  [9.0, 11.975545984516003, 14.951091969032005, 17.926637953548006]
# Trial #:  33
# Trustee:  C
# LLH:  36.8349274383296
# ...
# Trial #:  27
# Trustee:  A
# LLH:  29.344124205089845
# Trustee Prob:  0.9918976799671739
# Trustee Expected values:  [9.0, 11.951386079803044, 14.902772159606087, 17.85415823940913]
# Trial #:  28
# Trustee:  C
# LLH:  30.730418566209735
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  29
# Trustee:  B
# LLH:  31.7033314691096
# Trustee Prob:  0.9918976799671739
# Trustee Expected values:  [9.0, 11.951386079803044, 14.902772159606087, 17.85415823940913]
# Trial #:  30
# Trustee:  C
# LLH:  33.08962583022949
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  31
# Trustee:  C
# LLH:  34.475920191349374
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  32
# Trustee:  A
# LLH:  35.44883309424924
# Trustee Prob:  0.9959241709705362
# Trustee Expected values:  [9.0, 11.975545025823218, 14.951090051646435, 17.92663507746965]
# Trial #:  33
# Trustee:  C
# LLH:  36.835127455369125
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  34
# Trustee:  C
# LLH:  38.22142181648901
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  35
# Trustee:  B
# LLH:  39.82800318808507
# Trustee Prob:  0.9959241709705362
# Trustee Expected values:  [9.0, 11.975545025823218, 14.951090051646435, 17.92663507746965]
# Trial #:  36
# Trustee:  B
# LLH:  40.79802872177675
# Trustee Prob:  0.9979496758693663
# Trustee Expected values:  [9.0, 11.987698055216198, 14.975396110432396, 17.963094165648595]
# Trial #:  37
# Trustee:  C
# LLH:  42.18432308289664
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  38
# Trustee:  A
# LLH:  43.47377633784663
# Trustee Prob:  0.9979496758693663
# Trustee Expected values:  [9.0, 11.987698055216198, 14.975396110432396, 17.963094165648595]
# Trial #:  39
# Trustee:  C
# LLH:  44.86007069896652
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  40
# Trustee:  A
# LLH:  46.149379038452906
# Trustee Prob:  0.9989685953433597
# Trustee Expected values:  [9.0, 11.993811572060158, 14.987623144120317, 17.981434716180473]
# Trial #:  41
# Trustee:  B
# LLH:  47.438687377939296
# Trustee Prob:  0.9979496758693663
# Trustee Expected values:  [9.0, 11.987698055216198, 14.975396110432396, 17.963094165648595]
# Trial #:  42
# Trustee:  A
# LLH:  49.370700863292534
# Trustee Expected values:  [9.0, 11.993811572060158, 14.987623144120317, 17.981434716180473]
# Trial #:  43
# Trustee:  B
# LLH:  51.30147392490764
# Trustee Expected values:  [9.0, 11.987698055216198, 14.975396110432396, 17.963094165648595]
# Trial #:  44
# Trustee:  A
# LLH:  52.912098757076116
# Trustee Prob:  0.9994811573692933
# Trustee Expected values:  [9.0, 11.99688694421576, 14.99377388843152, 17.99066083264728]
# Trial #:  45
# Trustee:  C
# LLH:  54.298393118196
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  1
# Trustee:  B
# Trial #:  2
# Trustee:  A
# LLH:  1.3862943611198906
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  3
# Trustee:  A
# Trial #:  4
# Trustee:  B
# LLH:  2.772588722239781
# Trustee Prob:  0.7484776524517649
# Trustee Expected values:  [9.0, 10.49086591471059, 11.981731829421179, 13.472597744131768]
# Trial #:  5
# Trustee:  A
# LLH:  4.1588830833596715
# Trustee Prob:  0.7484776524517649
# Trustee Expected values:  [9.0, 10.49086591471059, 11.981731829421179, 13.472597744131768]
# Trial #:  6
# Trustee:  C
# LLH:  5.545177444479562
# Trustee Prob:  0.499999995
# Trustee Expected values:  [9.0, 8.99999997, 8.999999939999999, 8.99999991]
# Trial #:  7
# Trustee:  B
# LLH:  7.027446248267378
# Trustee Prob:  0.8734730173676497
# Trustee Expected values:  [9.0, 11.2408381042059, 13.481676208411796, 15.722514312617694]
# Trial #:  8
# Trustee:  B
# Trial #:  9
# Trustee:  A
# LLH:  8.509715052055194
# Trustee Prob:  0.8734730173676497
# Trustee Expected values:  [9.0, 11.2408381042059, 13.481676208411796, 15.722514312617694]
# Trial #:  10
# Trustee:  C
# LLH:  9.896009411564819
# Trustee Prob:  0.49999999
# Trustee Expected values:  [9.0, 8.99999994, 8.99999988, 8.99999982]
# Trial #:  11
# Trustee:  B
# LLH:  11.43845673359608
# Trustee Prob:  0.8734730086329195
# Trustee Expected values:  [9.0, 11.240838051797517, 13.481676103595035, 15.722514155392552]
# Trial #:  12
# Trustee:  B
# LLH:  12.740347855097323
# Trustee Prob:  0.8734729998981895
# Trustee Expected values:  [9.0, 11.240837999389136, 13.481675998778273, 15.722513998167411]
# Trial #:  13
# Trustee:  C
# LLH:  14.126642212996684
# Trustee Prob:  0.4999999850000001
# Trustee Expected values:  [9.0, 8.99999991, 8.999999820000001, 8.999999730000003]
# Trial #:  14
# Trustee:  B
# LLH:  15.428533335646371
# Trustee Prob:  0.9363512638123137
# Trustee Expected values:  [9.0, 11.618107582873883, 14.236215165747765, 16.854322748621648]
# Trial #:  15
# Trustee:  C
# LLH:  16.814827711258644
# Trustee Prob:  0.49999998000000023
# Trustee Expected values:  [9.0, 8.99999988, 8.999999760000003, 8.999999640000004]
# Trial #:  16
# Trustee:  A
# LLH:  17.876162629932978
# Trustee Prob:  0.936351272600233
# Trustee Expected values:  [9.0, 11.618107635601397, 14.236215271202795, 16.854322906804192]
# Trial #:  17
# Trustee:  A
# Trial #:  18
# Trustee:  B
# LLH:  18.88970114493104
# Trustee Prob:  0.9679818409111897
# Trustee Expected values:  [9.0, 11.807891045467137, 14.615782090934276, 17.423673136401415]
# Trial #:  19
# Trustee:  A
# LLH:  20.746409037941774
# Trustee Expected values:  [9.0, 11.618107635601397, 14.236215271202795, 16.854322906804192]
# Trial #:  20
# Trustee:  C
# LLH:  22.132703392620606
# Trustee Prob:  0.49999997500000043
# Trustee Expected values:  [9.0, 8.999999850000002, 8.999999700000005, 8.999999550000007]
# Trial #:  21
# Trustee:  B
# LLH:  23.122925916545803
# Trustee Prob:  0.9838934349236191
# Trustee Expected values:  [9.0, 11.903360609541714, 14.80672121908343, 17.710081828625146]
# Trial #:  22
# Trustee:  C
# LLH:  24.509220301819667
# Trustee Prob:  0.4999999700000007
# Trustee Expected values:  [9.0, 8.999999820000005, 8.99999964000001, 8.999999460000012]
# Trial #:  23
# Trustee:  A
# LLH:  26.084871733311132
# Trustee Prob:  0.9679818453319059
# Trustee Expected values:  [9.0, 11.807891071991435, 14.615782143982871, 17.423673215974308]
# Trial #:  24
# Trustee:  B
# LLH:  27.063547403584643
# Trustee Prob:  0.9918976778821005
# Trustee Expected values:  [9.0, 11.951386067292603, 14.902772134585206, 17.85415820187781]
# Trial #:  25
# Trustee:  C
# Trial #:  26
# Trustee:  A
# LLH:  28.0537699242849
# Trustee Prob:  0.9838934371474369
# Trustee Expected values:  [9.0, 11.903360622884621, 14.806721245769243, 17.710081868653866]
# Trial #:  27
# Trustee:  A
# LLH:  29.34412424668227
# Trustee Prob:  0.9918976790007803
# Trustee Expected values:  [9.0, 11.951386074004681, 14.902772148009364, 17.854158222014046]
# Trial #:  28
# Trustee:  C
# LLH:  30.73041863678693
# Trustee Prob:  0.499999965000001
# Trustee Expected values:  [9.0, 8.999999790000006, 8.999999580000011, 8.999999370000017]
# Trial #:  29
# Trustee:  B
# LLH:  31.70333154118399
# Trustee Prob:  0.9918976679631237
# Trustee Expected values:  [9.0, 11.951386007778742, 14.902772015557485, 17.854158023336225]
# Trial #:  30
# Trustee:  C
# LLH:  33.08962589103203
# Trustee Prob:  0.49999996000000135
# Trustee Expected values:  [9.0, 8.999999760000009, 8.999999520000017, 8.999999280000024]
# Trial #:  31
# Trustee:  C
# LLH:  34.47592026503404
# Trustee Prob:  0.4999999550000018
# Trustee Expected values:  [9.0, 8.99999973000001, 8.999999460000021, 8.999999190000032]
# Trial #:  32
# Trustee:  A
# LLH:  35.44883316862783
# Trustee Prob:  0.9959241704033738
# Trustee Expected values:  [9.0, 11.975545022420242, 14.951090044840486, 17.92663506726073]
# Trial #:  33
# Trustee:  C
# LLH:  36.8351275442401
# Trustee Prob:  0.49999995000000225
# Trustee Expected values:  [9.0, 8.999999700000014, 8.999999400000027, 8.999999100000041]
# Trial #:  34
# Trustee:  C
# LLH:  38.22142188925734
# Trustee Prob:  0.4999999450000027
# Trustee Expected values:  [9.0, 8.999999670000015, 8.999999340000032, 8.99999901000005]
# Trial #:  35
# Trustee:  B
# LLH:  39.82800325400918
# Trustee Prob:  0.9959241648509393
# Trustee Expected values:  [9.0, 11.975544989105636, 14.951089978211272, 17.926634967316907]
# Trial #:  36
# Trustee:  B
# LLH:  40.798028792083315
# Trustee Prob:  0.9979496727501773
# Trustee Expected values:  [9.0, 11.987698036501063, 14.975396073002127, 17.963094109503192]
# Trial #:  37
# Trustee:  C
# LLH:  42.18432320634194
# Trustee Prob:  0.49999994000000325
# Trustee Expected values:  [9.0, 8.99999964000002, 8.99999928000004, 8.999998920000058]
# Trial #:  38
# Trustee:  A
# LLH:  43.47377646133279
# Trustee Prob:  0.9979496755432999
# Trustee Expected values:  [9.0, 11.9876980532598, 14.9753961065196, 17.9630941597794]
# Trial #:  39
# Trustee:  C
# LLH:  44.8600708031295
# Trustee Prob:  0.49999993500000384
# Trustee Expected values:  [9.0, 8.999999610000023, 8.999999220000046, 8.999998830000068]
# Trial #:  40
# Trustee:  A
# LLH:  46.14937914263906
# Trustee Prob:  0.9989685951588305
# Trustee Expected values:  [9.0, 11.993811570952984, 14.987623141905967, 17.98143471285895]
# Trial #:  41
# Trustee:  B
# LLH:  47.438687482347106
# Trustee Prob:  0.9979496627706806
# Trustee Expected values:  [9.0, 11.987697976624084, 14.975395953248167, 17.96309392987225]
# Trial #:  42
# Trustee:  A
# LLH:  49.370700967475656
# Trustee Expected values:  [9.0, 11.993811570952984, 14.987623141905967, 17.98143471285895]
# Trial #:  43
# Trustee:  B
# LLH:  51.30147401314771
# Trustee Expected values:  [9.0, 11.987697976624084, 14.975395953248167, 17.96309392987225]
# Trial #:  44
# Trustee:  A
# LLH:  52.91209884521035
# Trustee Prob:  0.9994811572661528
# Trustee Expected values:  [9.0, 11.996886943596916, 14.993773887193834, 17.990660830790752]
# Trial #:  45
# Trustee:  C
# LLH:  54.298393143529914
# Trustee Expected values:  [9.0, 8.999999610000023, 8.999999220000046, 8.999998830000068]
# Trial #:  1
# Trustee:  B
# Trial #:  2
# Trustee:  A
# LLH:  1.3862943611198906
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  3
# Trustee:  A
# Trial #:  4
# Trustee:  B
# LLH:  2.772588722239781
# Trustee Prob:  0.7484776524517649
# Trustee Expected values:  [9.0, 10.49086591471059, 11.981731829421179, 13.472597744131768]
# Trial #:  5
# Trustee:  A
# LLH:  4.1588830833596715
# Trustee Prob:  0.7484776524517649
# Trustee Expected values:  [9.0, 10.49086591471059, 11.981731829421179, 13.472597744131768]
# Trial #:  6
# Trustee:  C
# LLH:  5.545177444479562
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  7
# Trustee:  B
# LLH:  7.027446258682859
# Trustee Prob:  0.8734730173676497
# Trustee Expected values:  [9.0, 11.2408381042059, 13.481676208411796, 15.722514312617694]
# Trial #:  8
# Trustee:  B
# Trial #:  9
# Trustee:  A
# LLH:  8.509715072886156
# Trustee Prob:  0.8734730173676497
# Trustee Expected values:  [9.0, 11.2408381042059, 13.481676208411796, 15.722514312617694]
# Trial #:  10
# Trustee:  C
# LLH:  9.896009434006046
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  11
# Trustee:  B
# LLH:  11.438456773871506
# Trustee Prob:  0.8734730173676497
# Trustee Expected values:  [9.0, 11.2408381042059, 13.481676208411796, 15.722514312617694]
# Trial #:  12
# Trustee:  B
# LLH:  12.74034788965012
# Trustee Prob:  0.8734730173676497
# Trustee Expected values:  [9.0, 11.2408381042059, 13.481676208411796, 15.722514312617694]
# Trial #:  13
# Trustee:  C
# LLH:  14.126642250770011
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  14
# Trustee:  B
# LLH:  15.428533366548626
# Trustee Prob:  0.936351272600233
# Trustee Expected values:  [9.0, 11.618107635601397, 14.236215271202795, 16.854322906804192]
# Trial #:  15
# Trustee:  C
# LLH:  16.814827727668515
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  16
# Trustee:  A
# LLH:  17.876162619360286
# Trustee Prob:  0.936351272600233
# Trustee Expected values:  [9.0, 11.618107635601397, 14.236215271202795, 16.854322906804192]
# Trial #:  17
# Trustee:  A
# Trial #:  18
# Trustee:  B
# LLH:  18.889701097539717
# Trustee Prob:  0.9679818453319059
# Trustee Expected values:  [9.0, 11.807891071991435, 14.615782143982871, 17.423673215974308]
# Trial #:  19
# Trustee:  A
# LLH:  20.746409038820183
# Trustee Expected values:  [9.0, 11.618107635601397, 14.236215271202795, 16.854322906804192]
# Trial #:  20
# Trustee:  C
# LLH:  22.132703399940073
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  21
# Trustee:  B
# LLH:  23.122925888838513
# Trustee Prob:  0.9838934371474369
# Trustee Expected values:  [9.0, 11.903360622884621, 14.806721245769243, 17.710081868653866]
# Trial #:  22
# Trustee:  C
# LLH:  24.509220249958403
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  23
# Trustee:  A
# LLH:  26.084871703538525
# Trustee Prob:  0.9679818453319059
# Trustee Expected values:  [9.0, 11.807891071991435, 14.615782143982871, 17.423673215974308]
# Trial #:  24
# Trustee:  B
# LLH:  27.063547339667544
# Trustee Prob:  0.9918976790007803
# Trustee Expected values:  [9.0, 11.951386074004681, 14.902772148009364, 17.854158222014046]
# Trial #:  25
# Trustee:  C
# Trial #:  26
# Trustee:  A
# LLH:  28.053769828565983
# Trustee Prob:  0.9838934371474369
# Trustee Expected values:  [9.0, 11.903360622884621, 14.806721245769243, 17.710081868653866]
# Trial #:  27
# Trustee:  A
# LLH:  29.344124147457787
# Trustee Prob:  0.9918976790007803
# Trustee Expected values:  [9.0, 11.951386074004681, 14.902772148009364, 17.854158222014046]
# Trial #:  28
# Trustee:  C
# LLH:  30.730418508577678
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  29
# Trustee:  B
# LLH:  31.70333137926924
# Trustee Prob:  0.9918976790007803
# Trustee Expected values:  [9.0, 11.951386074004681, 14.902772148009364, 17.854158222014046]
# Trial #:  30
# Trustee:  C
# LLH:  33.08962574038913
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  31
# Trustee:  C
# LLH:  34.47592010150902
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  32
# Trustee:  A
# LLH:  35.448832972200584
# Trustee Prob:  0.9959241704033738
# Trustee Expected values:  [9.0, 11.975545022420242, 14.951090044840486, 17.92663506726073]
# Trial #:  33
# Trustee:  C
# LLH:  36.83512733332047
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  34
# Trustee:  C
# LLH:  38.22142169444036
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  35
# Trustee:  B
# LLH:  39.82800309161092
# Trustee Prob:  0.9959241704033738
# Trustee Expected values:  [9.0, 11.975545022420242, 14.951090044840486, 17.92663506726073]
# Trial #:  36
# Trustee:  B
# LLH:  40.79802859262588
# Trustee Prob:  0.9979496755432999
# Trustee Expected values:  [9.0, 11.9876980532598, 14.9753961065196, 17.9630941597794]
# Trial #:  37
# Trustee:  C
# LLH:  42.18432295374577
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  38
# Trustee:  A
# LLH:  43.47377620540919
# Trustee Prob:  0.9979496755432999
# Trustee Expected values:  [9.0, 11.9876980532598, 14.9753961065196, 17.9630941597794]
# Trial #:  39
# Trustee:  C
# LLH:  44.860070566529075
# Trustee Prob:  0.5
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
# Trial #:  40
# Trustee:  A
# LLH:  46.149378902742356
# Trustee Prob:  0.9989685951588305
# Trustee Expected values:  [9.0, 11.993811570952984, 14.987623141905967, 17.98143471285895]
# Trial #:  41
# Trustee:  B
# LLH:  47.43868723895564
# Trustee Prob:  0.9979496755432999
# Trustee Expected values:  [9.0, 11.9876980532598, 14.9753961065196, 17.9630941597794]
# Trial #:  42
# Trustee:  A
# LLH:  49.37070078067994
# Trustee Expected values:  [9.0, 11.993811570952984, 14.987623141905967, 17.98143471285895]
# Trial #:  43
# Trustee:  B
# LLH:  51.30147389835586
# Trustee Expected values:  [9.0, 11.9876980532598, 14.9753961065196, 17.9630941597794]
# Trial #:  44
# Trustee:  A
# LLH:  52.91209875707614
# Trustee Prob:  0.9994811572661528
# Trustee Expected values:  [9.0, 11.996886943596916, 14.993773887193834, 17.990660830790752]
# Trial #:  45
# Trustee:  C
# LLH:  54.298393118196024
# Trustee Expected values:  [9.0, 9.0, 9.0, 9.0]
#       fun: 54.29839311819601
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-7.10542736e-07,  2.53339039e+00,  1.42108547e-06])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#    status: 0
#   success: True
#         x: array([0.4969553, 0.       , 0.107351 ])
