# %% [markdown]
# #SocialAL Model
#
# #Not working
#
# #Fit single alpha model to data - multiple subjects
#
# KLS 2.7.20
# Project info: https://osf.io/b48n2/
#
# Model modified from : Fareri, D. S., Chang, L. J., & Delgado, M. R. (2012). Effects of direct social experience on trust decisions and neural reward circuitry. Frontiers in Neuroscience, 6, 1–17. https://doi.org/10.3389/fnins.2012.00148

# %%
import sys
print(sys.version)
import numpy as np
import random
import math
import pandas as pd
from scipy.optimize import minimize
import os
from decimal import *
# Out:
# 3.7.3 (default, Mar 27 2019, 16:54:48)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
def update_value(Prob):
    invest = [0,3,6,9]
    retain = [9-x for x in invest] #print ("Retain list is: ", retain)
    shared = [2*x for x in invest] #print ("Shared list is: ", shared)
    EV = [(retain[x] + Prob*shared[x]) for x in range(0,4)]
    return EV

def update_prob(recip, Prob, alpha):
    Prob = Prob + alpha*(recip-Prob)
    return Prob

def get_action_selection_prob(beta, EV, choice):
    actionProb = Decimal(np.exp(beta*EV[choice-1])/np.sum([np.exp(beta*x) for x in EV]))
    return actionProb

def get_action_selection_probs(beta, EV):
    actionProbs = [get_action_selection_prob(beta, EV, x) for x in range(1,5)]
    return actionProbs

def get_likelihood_action(params, data):
    alpha = params[0]
    beta = params[1]
    
    # initialize variables
    prob = [0.5, 0.5, 0.5]
    ev = [[9,9,9,9],[9,9,9,9],[9,9,9,9]]
    
    totalLLH = 0 
    for trial in range(0, len(data)):
        trustee = data['Stim_Sequence'][trial] # get trustee type
        choice = data['Choice'][trial] # get choice made by participant
        response = data['Trustee_Response'][trial] # get response from trustee
        
        # compute the probability of selecting each option for that trustee
        probs = get_action_selection_probs(beta, ev[trustee])
        
        # use the probability of the selection (choice-probability) to update log likelihood
        if choice != 0:
            cprob = probs[choice-1] #print(cprob, isinstance(cprob, float))
            #print(cprob)

            #add to cumulative log likelihood
            totalLLH += -(math.log(cprob))
        
            # update prob and value
            if choice != 1:
                prob[trustee] = update_prob(response, prob[trustee], alpha)
            ev[trustee] = update_value(prob[trustee])
        
    return totalLLH

def model_fit_once(data):
        # initialize free parameters with randomly chosen numbers
        alpha=random.uniform(0, 1)
        beta=random.uniform(0, 1)
        params = [alpha, beta]
        
        #results = minimize(get_likelihood_action, 
                           #params, args =(data), method='BFGS', options = {'maxiter': 10000, 'disp': False})
        results = minimize(get_likelihood_action, 
                       params, args =(data), bounds = [(0, 1), (0, 1), (1e-10, 100)], 
                       options = {'maxiter': 10000, 'disp': False})
        return results

def model_fit(data):
    
    tries = 10 #  number of tries to find the best-fit parameter
    lowestLLH = math.inf 
    bestFit = 'NA'
    
    for i in range(tries):
        
        # initialize free parameters with randomly chosen numbers
        alpha=random.uniform(0, 1)
        beta=random.uniform(0, 1)
        params = [alpha, beta]

        # trying different solvers in the minimize call...
        results = minimize(get_likelihood_action, 
                           params, args =(data), bounds = [(0, 1), (1e-10, 20)], 
                           options = {'maxiter': 10000, 'disp': False})
        if (lowestLLH > results['fun'] and results['success']== True):
            lowestLLH = results['fun']
            bestFit = results
            
    return bestFit

# %% [markdown]
# Load and Clean Data

# %%
files = os.listdir('../data/modeling')

# %%
def load_and_clean(file):
    path = os.path.join('../data/modeling', file)
    dt = pd.read_csv(path)
    # recode trial type into numbers for model
    def stims(trial_type):
        if trial_type == "Trustworthy":
            return 0
        elif trial_type == "Neutral":
            return 1
        elif trial_type == "Untrustworthy":
            return 2
    dt['Stim_Sequence'] = dt['trial_type'].apply(stims)
    # rename response_key to choice
    def choices(response_key):
        if response_key == 'None':
            return 0 
        else:
            return response_key  
    dt['Choice'] = dt['response_key'].apply(choices)
    dt['Choice'] = pd.to_numeric(dt['Choice'])
    # calculte the trustee response
    def resp(trial_earnings):
        if trial_earnings >= 12:
            return 1
        else:
            return 0
    dt['Trustee_Response'] = dt['trial_earnings'].apply(resp)
    data = dt[['Stim_Sequence','Choice', 'Trustee_Response']]
    return(data)

# %% [markdown]
# Fit Model

# %%
print(getcontext())
params = [model_fit(load_and_clean(file)) for file in files]
# Out:
# Context(prec=28, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[InvalidOperation, DivisionByZero, Overflow])

# %%
params
# Out:
# [      fun: 47.03008544001793
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.13162821e-06, -1.66551217e-03])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 204
#        nit: 48
#     status: 0
#    success: True
#          x: array([3.09914204e-03, 2.00000000e+01]),
#        fun: 51.64479495954023
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.84217094e-06, 1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 42
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.21207545, 0.33599048]),
#        fun: 60.99695188927512
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([1.42108547e-06, 0.00000000e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 62.383246250395004
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 35.07775087930795
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([7.10542736e-06, 2.13162821e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 51
#        nit: 12
#     status: 0
#    success: True
#          x: array([0.1809365 , 1.09844269]),
#        fun: 59.61065752815523
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([1.42108547e-06, 0.00000000e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 62.383246250395004
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 60.99695188927512
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 34.59272230378004
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([7.10542736e-07, 0.00000000e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 36
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.84507034, 0.47871928]),
#        fun: 51.26226787896576
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.84217094e-06, 2.84217094e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 33
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.84225402, 0.24202534]),
#        fun: 59.33641697240585
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([1.10234524e+00, 3.69482223e-05])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 456
#        nit: 88
#     status: 0
#    success: True
#          x: array([3.94652688e-04, 1.57951328e+01]),
#        fun: 51.62389142589857
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-1.95603675e+00, -1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 30
#        nit: 7
#     status: 0
#    success: True
#          x: array([1.        , 0.11410217]),
#        fun: 44.97996758301955
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-5.81857407e+00,  8.52651283e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 42
#        nit: 8
#     status: 0
#    success: True
#          x: array([1.        , 0.28015365]),
#        fun: 60.99695188927512
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 3
#        nit: 0
#     status: 0
#    success: True
#          x: array([0.71914783, 0.71281269]),
#        fun: 37.068169005169096
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.84217094e-06, 1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 39
#        nit: 10
#     status: 0
#    success: True
#          x: array([0.48113686, 0.54726838]),
#        fun: 59.61065752815523
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 3
#        nit: 0
#     status: 0
#    success: True
#          x: array([0.48730952, 0.86771404]),
#        fun: 61.96603825312645
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 8.52651283e-06, -9.09494702e-05])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 48
#        nit: 13
#     status: 0
#    success: True
#          x: array([0.34718773, 0.05450228]),
#        fun: 57.521392999138214
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([4.26325641e-06, 4.97379915e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 57
#        nit: 12
#     status: 0
#    success: True
#          x: array([0.30681942, 0.0951357 ]),
#        fun: 57.08992751906718
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 2.42636133e-02, -7.74491582e-05])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 363
#        nit: 86
#     status: 0
#    success: True
#          x: array([1.17454567e-03, 2.00000000e+01]),
#        fun: 36.12953881418881
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.84217094e-06, 2.13162821e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 36
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.38160603, 0.62988705]),
#        fun: 42.405819226845274
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 7.10542736e-07, -7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 66
#        nit: 14
#     status: 0
#    success: True
#          x: array([0.64142794, 0.37843355]),
#        fun: 37.70133516457724
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 1.42108547e-06, -7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 36
#        nit: 10
#     status: 0
#    success: True
#          x: array([0.3980924 , 0.64111366]),
#        fun: 36.327698024478146
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([7.10542736e-07, 2.13162821e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 27
#        nit: 6
#     status: 0
#    success: True
#          x: array([0.76274192, 0.47769416]),
#        fun: 57.03176472826796
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-4.68958206e-05, -4.97379915e-06])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 60
#        nit: 16
#     status: 0
#    success: True
#          x: array([0.09840195, 0.50332978]),
#        fun: 41.11668192711214
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([1.42108547e-06, 3.55271368e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 39
#        nit: 10
#     status: 0
#    success: True
#          x: array([0.18720348, 0.75951053]),
#        fun: 56.389756760390476
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.13162821e-06, 1.13686838e-05])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 42
#        nit: 11
#     status: 0
#    success: True
#          x: array([0.8961185 , 0.18219564]),
#        fun: 47.761701332574525
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.13162821e-06, 2.13162821e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 36
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.62938295, 0.35162929]),
#        fun: 46.68535690027159
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 0.00556923, -0.00084057])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 192
#        nit: 44
#     status: 0
#    success: True
#          x: array([3.76521926e-03, 2.00000000e+01]),
#        fun: 48.242806807502234
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-1.42108547e-06,  2.84217094e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 39
#        nit: 10
#     status: 0
#    success: True
#          x: array([0.75447102, 0.3019802 ]),
#        fun: 62.38161069897559
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 1.55608859e-04, -7.10542736e-06])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 15
#        nit: 4
#     status: 0
#    success: True
#          x: array([4.77194899e-04, 9.15820826e-01]),
#        fun: 59.91486092724669
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-0.13655637,  0.        ])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 42
#        nit: 11
#     status: 0
#    success: True
#          x: array([1.        , 0.06912118]),
#        fun: 57.846265724433955
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-3.97903932e-05, -1.98951966e-05])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 27
#        nit: 7
#     status: 0
#    success: True
#          x: array([0.56287816, 0.17249645]),
#        fun: 10.300203805771352
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 1.06581410e-06, -3.55271368e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 45
#        nit: 11
#     status: 0
#    success: True
#          x: array([0.56844734, 2.162599  ]),
#        fun: 36.46911358082961
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-6.87176112,  0.        ])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 27
#        nit: 7
#     status: 0
#    success: True
#          x: array([1.        , 0.42303645]),
#        fun: 54.585524132371916
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.91534263e-01,  3.55271368e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 42
#        nit: 11
#     status: 0
#    success: True
#          x: array([1.        , 0.19435666]),
#        fun: 37.26323911833462
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([3.55271368e-06, 3.55271368e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 27
#        nit: 7
#     status: 0
#    success: True
#          x: array([0.60051001, 0.53338994]),
#        fun: 41.370677358682606
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0.00000000e+00, 7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 36
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.3189252 , 0.55008071]),
#        fun: 60.99695188927512
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 43.745894972549785
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([7.10542736e-07, 1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 21
#        nit: 5
#     status: 0
#    success: True
#          x: array([0.27718301, 0.51517585]),
#        fun: 57.703980218999256
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-4.26325641e-06, -1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 63
#        nit: 13
#     status: 0
#    success: True
#          x: array([0.10533956, 0.36753267]),
#        fun: 33.4934323957204
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([7.10542736e-07, 1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 39
#        nit: 10
#     status: 0
#    success: True
#          x: array([0.94244893, 0.47376845]),
#        fun: 38.12222002897807
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.84217094e-06, -4.26325641e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 30
#        nit: 8
#     status: 0
#    success: True
#          x: array([0.80873036, 0.45698011]),
#        fun: 38.533725711928994
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-3.72321551e-01, -7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 39
#        nit: 10
#     status: 0
#    success: True
#          x: array([1.        , 0.38186825]),
#        fun: 62.383246250395004
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 33.45833719362474
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 0.00032969, -0.00120792])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 234
#        nit: 48
#     status: 0
#    success: True
#          x: array([9.38249813e-03, 2.00000000e+01]),
#        fun: 55.709305671847304
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([7.10542736e-06, 2.84217094e-05])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 39
#        nit: 10
#     status: 0
#    success: True
#          x: array([0.4886623 , 0.16523725]),
#        fun: 39.1608388995476
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([7.10542736e-07, 1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 27
#        nit: 6
#     status: 0
#    success: True
#          x: array([0.68441491, 0.48068301]),
#        fun: 47.83642976145546
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0.00000000e+00, 1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 30
#        nit: 8
#     status: 0
#    success: True
#          x: array([0.49846002, 0.38644688]),
#        fun: 34.592722303780036
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.84217094e-06, -2.84217094e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 33
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.84507033, 0.47871929]),
#        fun: 46.55177292856636
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.13162821e-06, 4.97379915e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 33
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.34476364, 0.48415749]),
#        fun: 27.527882219366155
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-3.19744231e-06, -3.19744231e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 45
#        nit: 13
#     status: 0
#    success: True
#          x: array([0.15202572, 2.16517292]),
#        fun: 36.698644690898625
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-7.10542736e-07, -1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 33
#        nit: 8
#     status: 0
#    success: True
#          x: array([0.64464646, 0.5849109 ]),
#        fun: 46.65022737030312
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([4.97379915e-06, 8.52651283e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 33
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.37900876, 0.45137566]),
#        fun: 42.40783724761245
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.13162821e-06, -1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 48
#        nit: 13
#     status: 0
#    success: True
#          x: array([0.35008378, 0.49349437]),
#        fun: 55.45177444479557
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([7.10542736e-07, 0.00000000e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 59.3558234269309
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-3.55271368e-06,  7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 33
#        nit: 6
#     status: 0
#    success: True
#          x: array([0.60506302, 0.14119803]),
#        fun: 47.87758945397572
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.84217094e-06, 0.00000000e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 57
#        nit: 15
#     status: 0
#    success: True
#          x: array([0.12770142, 0.54936007]),
#        fun: 60.99695188927512
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 50.730065357749446
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 9.44240242e-03, -9.87654403e-05])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 447
#        nit: 98
#     status: 0
#    success: True
#          x: array([2.47674864e-03, 2.00000000e+01]),
#        fun: 60.99695188927512
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 53.308745347288266
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.02917079e+00, -7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 27
#        nit: 7
#     status: 0
#    success: True
#          x: array([1.        , 0.18228971]),
#        fun: 42.30443586148869
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0.00000000e+00, 1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 21
#        nit: 5
#     status: 0
#    success: True
#          x: array([0.61929633, 0.41580603]),
#        fun: 58.22436316703534
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.13162821e-06, 0.00000000e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 43.06087998290555
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-1.42108547e-06,  7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 33
#        nit: 8
#     status: 0
#    success: True
#          x: array([0.46395394, 0.42729295]),
#        fun: 49.902695860418994
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([1.42108547e-06, 7.81597009e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 51
#        nit: 14
#     status: 0
#    success: True
#          x: array([0.59958101, 0.14617043]),
#        fun: 36.83686882968608
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-8.3248878e+00,  9.9475983e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 42
#        nit: 9
#     status: 0
#    success: True
#          x: array([1.        , 0.45632739]),
#        fun: 53.16311468249527
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([ 0.00398543, -0.00059401])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 324
#        nit: 68
#     status: 0
#    success: True
#          x: array([1.4826625e-03, 2.0000000e+01]),
#        fun: 54.49333181197561
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.13162821e-06, -7.81597009e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 39
#        nit: 10
#     status: 0
#    success: True
#          x: array([0.9352321 , 0.18688862]),
#        fun: 62.383246250395004
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0., 0.])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10]),
#        fun: 50.237647087183944
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-2.25255263e+00,  7.10542736e-07])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 54
#        nit: 10
#     status: 0
#    success: True
#          x: array([1.        , 0.21207239]),
#        fun: 34.81359718991659
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([0.00000000e+00, 1.42108547e-06])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 42
#        nit: 11
#     status: 0
#    success: True
#          x: array([0.48288098, 0.6157203 ]),
#        fun: 60.9967319871324
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([-3.55271368e-06, -1.98951966e-05])
#    message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#       nfev: 30
#        nit: 9
#     status: 0
#    success: True
#          x: array([0.31270503, 0.00142073]),
#        fun: 62.383246250395004
#   hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#        jac: array([2.13162821e-06, 0.00000000e+00])
#    message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#       nfev: 6
#        nit: 1
#     status: 0
#    success: True
#          x: array([0.e+00, 1.e-10])]

# %%
params = pd.DataFrame(params)
params['id'] = [file[:-4] for file in files]
params['alpha'] = [params['x'][y][0] for y in range(len(params))]
params['beta'] = [params['x'][y][1] for y in range(len(params))]
params['-LLH'] = [params['fun'][y] for y in range(len(params))]
params = params[['id', 'alpha', 'beta', '-LLH']]
print(params)
# Out:
#           id     alpha          beta       -LLH
# 0   sub-2013  0.003099  2.000000e+01  47.030085
# 1   sub-2007  0.212075  3.359905e-01  51.644795
# 2   sub-2006  0.000000  1.000000e-10  60.996952
# 3   sub-2012  0.000000  1.000000e-10  62.383246
# 4   sub-2004  0.180936  1.098443e+00  35.077751
# 5   sub-2010  0.000000  1.000000e-10  59.610658
# 6   sub-2038  0.000000  1.000000e-10  62.383246
# 7   sub-1040  0.000000  1.000000e-10  60.996952
# 8   sub-2039  0.845070  4.787193e-01  34.592722
# 9   sub-2011  0.842254  2.420253e-01  51.262268
# 10  sub-2005  0.000395  1.579513e+01  59.336417
# 11  sub-2029  1.000000  1.141022e-01  51.623891
# 12  sub-2001  1.000000  2.801536e-01  44.979968
# 13  sub-2015  0.719148  7.128127e-01  60.996952
# 14  sub-2014  0.481137  5.472684e-01  37.068169
# 15  sub-2016  0.487310  8.677140e-01  59.610658
# 16  sub-2002  0.347188  5.450228e-02  61.966038
# 17  sub-2003  0.306819  9.513570e-02  57.521393
# 18  sub-1009  0.001175  2.000000e+01  57.089928
# 19  sub-1021  0.381606  6.298871e-01  36.129539
# 20  sub-1035  0.641428  3.784335e-01  42.405819
# 21  sub-1034  0.398092  6.411137e-01  37.701335
# 22  sub-1020  0.762742  4.776942e-01  36.327698
# 23  sub-1008  0.098402  5.033298e-01  57.031765
# 24  sub-1036  0.187203  7.595105e-01  41.116682
# 25  sub-1022  0.896119  1.821956e-01  56.389757
# 26  sub-1023  0.629383  3.516293e-01  47.761701
# 27  sub-1037  0.003765  2.000000e+01  46.685357
# 28  sub-1033  0.754471  3.019802e-01  48.242807
# 29  sub-1027  0.000477  9.158208e-01  62.381611
# ..       ...       ...           ...        ...
# 43  sub-1016  0.000000  1.000000e-10  62.383246
# 44  sub-1012  0.009382  2.000000e+01  33.458337
# 45  sub-1006  0.488662  1.652372e-01  55.709306
# 46  sub-1007  0.684415  4.806830e-01  39.160839
# 47  sub-1013  0.498460  3.864469e-01  47.836430
# 48  sub-2040  0.845070  4.787193e-01  34.592722
# 49  sub-1005  0.344764  4.841575e-01  46.551773
# 50  sub-1039  0.152026  2.165173e+00  27.527882
# 51  sub-1038  0.644646  5.849109e-01  36.698645
# 52  sub-1010  0.379009  4.513757e-01  46.650227
# 53  sub-1004  0.350084  4.934944e-01  42.407837
# 54  sub-2032  0.000000  1.000000e-10  55.451774
# 55  sub-2026  0.605063  1.411980e-01  59.355823
# 56  sub-2027  0.127701  5.493601e-01  47.877589
# 57  sub-2033  0.000000  1.000000e-10  60.996952
# 58  sub-2025  0.002477  2.000000e+01  50.730065
# 59  sub-2031  0.000000  1.000000e-10  60.996952
# 60  sub-2019  1.000000  1.822897e-01  53.308745
# 61  sub-2018  0.619296  4.158060e-01  42.304436
# 62  sub-2030  0.000000  1.000000e-10  58.224363
# 63  sub-2024  0.463954  4.272929e-01  43.060880
# 64  sub-2008  0.599581  1.461704e-01  49.902696
# 65  sub-2020  1.000000  4.563274e-01  36.836869
# 66  sub-2034  0.001483  2.000000e+01  53.163115
# 67  sub-2021  0.935232  1.868886e-01  54.493332
# 68  sub-2009  0.000000  1.000000e-10  62.383246
# 69  sub-2037  1.000000  2.120724e-01  50.237647
# 70  sub-2023  0.482881  6.157203e-01  34.813597
# 71  sub-2022  0.312705  1.420729e-03  60.996732
# 72  sub-2036  0.000000  1.000000e-10  62.383246
#
# [73 rows x 4 columns]

# %%
# save parameters in text file
params.to_csv(path_or_buf = '../output/single_alpha_model_params.csv', index = False)
